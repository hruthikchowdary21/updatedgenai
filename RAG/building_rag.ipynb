# %%
import pdfplumber
import re
import spacy

# Load the English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load("en_core_web_sm")

# %%
def extract_text_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        full_text = ""
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                full_text += text + "\n"
    return full_text

pdf_path = 'C:/Users/hruth/GENAI/RAG/constitution.pdf'  # Make sure the path is correct
constitution_text = extract_text_from_pdf(pdf_path)

# %%
print(constitution_text[:500])  # Print the first 500 characters to verify content
# Out:
# CONSTITUTION OF THE UNITED STATES OF AMERICA—17871
# WETHEPEOPLEof the United States, in Order to SECTION. 2. 1The House of Representatives
# form a more perfect Union, establish Justice, shall be composed of Members chosen every sec-
# insure domestic Tranquility, provide for the ond Year by the People of the several States,
# common defence, promote the general Welfare, and the Electors in each State shall have the
# and secure the Blessings of Liberty to our- Qualifications requisite for Electors of th

# %%
def clean_and_segment_text(text):
    # Clean text
    text = re.sub(r'\s+', ' ', text)
    # Assuming each article starts with "Article" followed by Roman numerals
    articles = re.split(r'(?=Article\s+[IVXLCDM]+)', text)
    return articles

cleaned_articles = clean_and_segment_text(constitution_text)

# %%
def extract_entities(articles):
    entities = []
    for article in articles:
        doc = nlp(article)
        article_entities = []
        for ent in doc.ents:
            article_entities.append((ent.text, ent.label_))
        entities.append(article_entities)
    return entities

constitution_entities = extract_entities(cleaned_articles)

# %%
# Print entities from the first article
for entity in constitution_entities[0]:
    print(entity)
# Out:
# ('the United States', 'GPE')
# ('Order', 'PERSON')
# ('2', 'CARDINAL')
# ('1The', 'CARDINAL')
# ('House of Representatives', 'ORG')
# ('Justice', 'ORG')
# ('Tranquility', 'ORG')
# ('the ond Year', 'DATE')
# ('States', 'GPE')
# ('State', 'ORG')
# ('the Blessings of Liberty', 'ORG')
# ('Qualifications', 'NORP')
# ('Branch', 'PERSON')
# ('the State Legislature', 'ORG')
# ('Constitution', 'LAW')
# ('the United States', 'GPE')
# ('2No', 'CARDINAL')
# ('America', 'GPE')
# ('seven Years', 'DATE')
# ('ARTICLE', 'FAC')
# ('I. United States', 'GPE')
# ('State', 'ORG')
# ('Congress', 'ORG')
# ('Senate', 'ORG')
# ('3Representatives', 'CARDINAL')
# ('Taxes', 'ORG')
# ('House of Representatives', 'ORG')
# ('States', 'GPE')
# ('Numbers', 'ORG')
# ('Constitution', 'LAW')
# ('Washington', 'PERSON')
# ('12', 'CARDINAL')
# ('States', 'GPE')
# ('Indians', 'NORP')
# ('three fifths', 'CARDINAL')
# ('May 1785', 'DATE')
# ('Congress', 'ORG')
# ('three Years', 'DATE')
# ('the Articles of Confederation', 'ORG')
# ('first', 'ORDINAL')
# ('Congress', 'ORG')
# ('January 1786', 'DATE')
# ('the Legislature United States', 'ORG')
# ('Virginia', 'GPE')
# ('Term of ten Years', 'ORG')
# ('Manner', 'PERSON')
# ('five', 'CARDINAL')
# ('three', 'CARDINAL')
# ('States', 'GPE')
# ('Law', 'PERSON')
# ('The Number of Representatives Union', 'ORG')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('at Least one', 'CARDINAL')
# ('the State of New Hampshire', 'ORG')
# ('United', 'ORG')
# ('three', 'CARDINAL')
# ('Massachusetts', 'GPE')
# ('eight', 'CARDINAL')
# ('Rhode- States', 'PERSON')
# ('Congress', 'ORG')
# ('The Vir- Island', 'LOC')
# ('the first Monday', 'DATE')
# ('September', 'DATE')
# ('Annapolis', 'ORG')
# ('five', 'CARDINAL')
# ('New-York', 'GPE')
# ('six', 'CARDINAL')
# ('New Jersey', 'GPE')
# ('four', 'CARDINAL')
# ('only four', 'CARDINAL')
# ('States', 'GPE')
# ('Pennsylvania', 'GPE')
# ('eight', 'CARDINAL')
# ('Delaware', 'GPE')
# ('Maryland', 'GPE')
# ('Delaware', 'GPE')
# ('New York', 'GPE')
# ('New Jersey', 'GPE')
# ('Pennsyl-', 'ORG')
# ('six', 'CARDINAL')
# ('Virginia', 'GPE')
# ('ten', 'CARDINAL')
# ('North Carolina', 'GPE')
# ('five', 'CARDINAL')
# ('South', 'LOC')
# ('Massachusetts', 'GPE')
# ('New Carolina', 'GPE')
# ('five', 'CARDINAL')
# ('Georgia', 'GPE')
# ('three', 'CARDINAL')
# ('North Carolina', 'GPE')
# ('Rhode Island', 'GPE')
# ('Representation', 'LOC')
# ('Hamil-', 'PERSON')
# ('State', 'ORG')
# ('the Executive Authority', 'ORG')
# ('New York', 'GPE')
# ('5The House of Representatives', 'ORG')
# ('States', 'GPE')
# ('Officers', 'WORK_OF_ART')
# ('Philadelphia', 'GPE')
# ('the Second Monday of May', 'DATE')
# ('Power of Impeachment', 'ORG')
# ('the United States', 'GPE')
# ('3', 'CARDINAL')
# ('1The', 'CARDINAL')
# ('Senate', 'ORG')
# ('the United States', 'GPE')
# ('the Constitution of the Federal Government', 'LAW')
# ('two', 'CARDINAL')
# ('Union', 'ORG')
# ('State', 'ORG')
# ('Legislature', 'ORG')
# ('six', 'CARDINAL')
# ('the United States', 'GPE')
# ('Congress', 'ORG')
# ('Years', 'DATE')
# ('one', 'CARDINAL')
# ('the Legislatures of every State', 'ORG')
# ('Congress', 'ORG')
# ('the 21st of February, 1787', 'DATE')
# ('States', 'GPE')
# ('State', 'ORG')
# ('Delaware', 'GPE')
# ('December 7, 1787', 'DATE')
# ('Rhode Island', 'GPE')
# ('Pennsylvania', 'GPE')
# ('December 12, 1787', 'DATE')
# ('New Jersey', 'GPE')
# ('December 18, 1787', 'DATE')
# ('the 25th of May', 'DATE')
# ('seven', 'CARDINAL')
# ('States', 'GPE')
# ('Georgia', 'GPE')
# ('January 2, 1788', 'DATE')
# ('Connecticut', 'GPE')
# ('January 9, 1788', 'DATE')
# ('Massa-', 'PERSON')
# ('George Washington', 'PERSON')
# ('Virginia', 'GPE')
# ('chusetts', 'PERSON')
# ('February 6, 1788', 'DATE')
# ('Maryland', 'GPE')
# ('April 28, 1788', 'DATE')
# ('South Caro-', 'LOC')
# ('May 23, 1788', 'DATE')
# ('New Hampshire', 'GPE')
# ('June 21, 1788', 'DATE')
# ('Virginia', 'GPE')
# ('June', 'DATE')
# ('the 17th of September, 1787', 'DATE')
# ('25, 1788', 'DATE')
# ('New York', 'GPE')
# ('July 26, 1788', 'DATE')
# ('Congress', 'ORG')
# ('the 28th of January, 1790', 'DATE')
# ('Gerry', 'PERSON')
# ('Massachusetts', 'GPE')
# ('North Carolina', 'GPE')
# ('the Constitution November 21', 'LAW')
# ('Mason', 'PERSON')
# ('Randolph', 'ORG')
# ('Virginia', 'GPE')
# ('1789', 'DATE')
# ('Congress', 'ORG')
# ('the 1st of June, 1790', 'DATE')
# ('Congress', 'ORG')
# ('Rhode Island', 'GPE')
# ('Federal Government', 'ORG')
# ('the Constitution January 10, 1791', 'LAW')
# ('Congress', 'ORG')
# ('the 28th', 'DATE')
# ('Congress', 'ORG')
# ('February 18, 1791', 'DATE')
# ('1787', 'DATE')
# ('Constitution', 'LAW')
# ('Union', 'ORG')
# ('the United States', 'GPE')
# ('Legislatures', 'PERSON')
# ('2The', 'CARDINAL')
# ('State', 'ORG')
# ('States', 'GPE')
# ('section 2', 'LAW')
# ('XIV', 'ORG')
# ('the 4th of March, 1789', 'DATE')
# ('the day', 'DATE')
# ('1', 'CARDINAL')
# ('Secrecy', 'ORG')
# ('Consequence', 'ORG')
# ('first', 'ORDINAL')
# ('House', 'ORG')
# ('three', 'CARDINAL')
# ('Classes', 'PRODUCT')
# ('The Seats of the Senators', 'WORK_OF_ART')
# ('first', 'ORDINAL')
# ('Journal', 'ORG')
# ('the second Year', 'DATE')
# ('House', 'ORG')
# ('second', 'ORDINAL')
# ('fourth Year', 'DATE')
# ('third', 'ORDINAL')
# ('more than three days', 'DATE')
# ('the sixth Year', 'DATE')
# ('two', 'CARDINAL')
# ('Houses', 'ORG')
# ('every second Year', 'DATE')
# ('Vacancies', 'ORG')
# ('6', 'CARDINAL')
# ('1The', 'CARDINAL')
# ('State', 'ORG')
# ('Law', 'PERSON')
# ('Appoint- Treasury', 'ORG')
# ('United States.6They', 'ORG')
# ('Treason', 'PERSON')
# ('Felony', 'ORG')
# ('Breach', 'PERSON')
# ('Arrest', 'PERSON')
# ('3No Person', 'FAC')
# ('Attendance', 'PERSON')
# ('the Age of thirty Years', 'DATE')
# ('Houses', 'ORG')
# ('nine Years', 'EVENT')
# ('the United States', 'GPE')
# ('Speech', 'PERSON')
# ('State', 'ORG')
# ('4The', 'CARDINAL')
# ('the United States', 'GPE')
# ('2No', 'CARDINAL')
# ('Senate', 'ORG')
# ('Time', 'ORG')
# ('the Authority of the 5The', 'ORG')
# ('Senate', 'ORG')
# ('Officers', 'GPE')
# ('United States', 'GPE')
# ('Emoluments', 'ORG')
# ('the Office of President', 'ORG')
# ('the United States', 'GPE')
# ('States', 'GPE')
# ('House', 'ORG')
# ('6The', 'CARDINAL')
# ('Senate', 'ORG')
# ('Office', 'GPE')
# ('1All', 'CARDINAL')
# ('Oath or Affirmation', 'ORG')
# ('the House of Representatives', 'ORG')
# ('the United States', 'GPE')
# ('Senate', 'ORG')
# ('Amend- tried', 'PERSON')
# ('Bills', 'ORG')
# ('House', 'ORG')
# ('two thirds', 'CARDINAL')
# ('Representatives', 'ORG')
# ('Senate', 'ORG')
# ('7Judgment', 'CARDINAL')
# ('Cases of Impeachment', 'ORG')
# ('Office', 'ORG')
# ('the United States', 'GPE')
# ('the United States', 'GPE')
# ('House', 'ORG')
# ('Party', 'ORG')
# ('Indictment, Trial', 'ORG')
# ('Journal', 'ORG')
# ('Punishment', 'ORG')
# ('Law', 'PERSON')
# ('two thirds', 'CARDINAL')
# ('4', 'CARDINAL')
# ('1The', 'CARDINAL')
# ('Manner', 'PERSON')
# ('House', 'ORG')
# ('Bill', 'PERSON')
# ('Representa-', 'PERSON')
# ('State', 'ORG')
# ('House', 'ORG')
# ('Legislature', 'ORG')
# ('Congress', 'ORG')
# ('two thirds', 'CARDINAL')
# ('Law', 'PERSON')
# ('House', 'ORG')
# ('2The', 'CARDINAL')
# ('Congress', 'ORG')
# ('Bill', 'PERSON')
# ('the Journal of each', 'ORG')
# ('House', 'ORG')
# ('first', 'ORDINAL')
# ('Monday', 'DATE')
# ('Bill', 'PERSON')
# ('Law', 'PERSON')
# ('ten Days', 'DATE')
# ('Sundays', 'DATE')
# ('5', 'CARDINAL')
# ('House', 'ORG')
# ('Law', 'PERSON')
# ('Manner', 'PERSON')
# ('Congress', 'ORG')
# ('Adjourn-', 'PERSON')
# ('Quorum', 'GPE')
# ('Attendance', 'PERSON')
# ('Manner', 'PERSON')
# ('Senate', 'ORG')
# ('House', 'ORG')
# ('House', 'ORG')
# ('House', 'ORG')
# ('Proceedings', 'ORG')
# ('the United States', 'GPE')
# ('two', 'CARDINAL')
# ('thirds', 'CARDINAL')
# ('House', 'ORG')
# ('Journal', 'ORG')
# ('two thirds', 'CARDINAL')
# ('Senate', 'ORG')
# ('House', 'ORG')
# ('Representatives', 'ORG')
# ('Rules', 'NORP')
# ('Limitations', 'ORG')
# ('8', 'CARDINAL')
# ('Congress', 'ORG')
# ('Taxes', 'ORG')
# ('4', 'CARDINAL')
# ('2', 'CARDINAL')
# ('XX', 'GPE')
# ('XXVII', 'GPE')
# ('THE UNITED STATES OF AMERICA—1787', 'ORG')
# ('Debts', 'PERSON')
# ('Defence', 'ORG')
# ('United', 'ORG')
# ('the United States', 'GPE')
# ('2To', 'CARDINAL')
# ('the United 4No Capitation', 'ORG')
# ('States', 'GPE')
# ('Proportion', 'ORG')
# ('Census', 'PERSON')
# ('3To', 'CARDINAL')
# ('Commerce', 'ORG')
# ('States', 'GPE')
# ('Articles', 'GPE')
# ('Tribes', 'PERSON')
# ('State', 'ORG')
# ('4To', 'CARDINAL')
# ('Commerce', 'ORG')
# ('Ports', 'ORG')
# ('the United States', 'GPE')
# ('one', 'CARDINAL')
# ('State', 'ORG')
# ('coin Money', 'ORG')
# ('Value', 'ORG')
# ('one', 'CARDINAL')
# ('State', 'ORG')
# ('Coin', 'ORG')
# ('Measures', 'PERSON')
# ('7No Money', 'ORG')
# ('Treasury', 'ORG')
# ('6To', 'ORG')
# ('Consequence of Appropriations', 'ORG')
# ('Coin of the Law', 'ORG')
# ('Statement and Account', 'ORG')
# ('United States', 'GPE')
# ('7To', 'CARDINAL')
# ('Post Offices', 'ORG')
# ('8To', 'CARDINAL')
# ('the Progress of Science', 'ORG')
# ('8No', 'CARDINAL')
# ('Arts', 'ORG')
# ('Times', 'ORG')
# ('United States', 'GPE')
# ('Profit or Trust', 'ORG')
# ('Writings', 'PERSON')
# ('Discoveries', 'ORG')
# ('Congress', 'ORG')
# ('9To', 'CARDINAL')
# ('the su- Emolument, Office', 'ORG')
# ('Title', 'PERSON')
# ('King', 'PERSON')
# ('State', 'ORG')
# ('10To', 'CARDINAL')
# ('Piracies and Felonies SECTION', 'ORG')
# ('10.', 'CARDINAL')
# ('1No', 'CARDINAL')
# ('State', 'ORG')
# ('Offences Treaty', 'WORK_OF_ART')
# ('Alliance', 'ORG')
# ('Confederation', 'ORG')
# ('Marque', 'NORP')
# ('Reprisal', 'ORG')
# ('coin Money', 'ORG')
# ('War', 'DATE')
# ('Letters of Marque', 'ORG')
# ('Bills of Credit', 'ORG')
# ('Reprisal', 'ORG')
# ('Captures ver Coin a Tender in Payment of Debts', 'ORG')
# ('Land and Water', 'WORK_OF_ART')
# ('Bill of Attainder', 'PERSON')
# ('Law', 'PERSON')
# ('Law', 'PERSON')
# ('12To', 'CARDINAL')
# ('Armies', 'ORG')
# ('Appro-', 'ORG')
# ('the Obligation of Contracts', 'ORG')
# ('Title of Nobility', 'ORG')
# ('2No', 'CARDINAL')
# ('13To', 'DATE')
# ('Navy', 'ORG')
# ('Congress', 'ORG')
# ('Imposts or Duties on Imports 14To', 'WORK_OF_ART')
# ('15To', 'CARDINAL')
# ('the Laws of the Union', 'WORK_OF_ART')
# ('Insur-', 'GPE')
# ('Treasury', 'ORG')
# ('the United States', 'GPE')
# ('16To', 'DATE')
# ('Controul of the Congress', 'ORG')
# ('3No State', 'PERCENT')
# ('the United States', 'GPE')
# ('Duty of Tonnage', 'WORK_OF_ART')
# ('the Appointment of the Officers', 'WORK_OF_ART')
# ('Ships of War', 'ORG')
# ('Peace', 'LOC')
# ('Authority', 'ORG')
# ('State', 'ORG')
# ('Congress', 'ORG')
# ('War', 'GPE')
# ('Cases', 'ORG')
# ('Danger', 'PERSON')
# ('ten Miles square', 'QUANTITY')
# ('Cession', 'PERSON')
# ('the Acceptance of Congress', 'ORG')
# ('ARTICLE', 'LAW')
# ('the United States', 'GPE')
# ('Authority', 'ORG')
# ('1', 'CARDINAL')
# ('1The', 'CARDINAL')
# ('the Consent of the Legisla-', 'PRODUCT')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('America', 'GPE')
# ('the the Erection of Forts, Magazines, Arsenals', 'ORG')
# ('Buildings;—And', 'NORP')
# ('18To', 'CARDINAL')
# ('Laws', 'PERSON')
# ('2Each State', 'ORG')
# ('Manner', 'PERSON')
# ('Powers', 'ORG')
# ('Powers', 'ORG')
# ('Legislature', 'ORG')
# ('Constitution', 'LAW')
# ('United States', 'GPE')
# ('Department', 'ORG')
# ('Officer and Representatives', 'ORG')
# ('State', 'ORG')
# ('Congress', 'ORG')
# ('9', 'CARDINAL')
# ('1The', 'CARDINAL')
# ('Office of Trust', 'ORG')
# ('Profit', 'ORG')
# ('the United States', 'GPE')
# ('Congress', 'ORG')
# ('3The', 'CARDINAL')
# ('eight hundred and eight', 'CARDINAL')
# ('Ballot', 'ORG')
# ('two', 'CARDINAL')
# ('ten dollars', 'MONEY')
# ('State', 'ORG')
# ('2The', 'CARDINAL')
# ('Habeas Corpus', 'PERSON')
# ('THE UNITED STATES OF AMERICA—1787 Page IV', 'ORG')
# ('Persons', 'ORG')
# ('United States', 'GPE')
# ('the United States', 'GPE')
# ('Opinion', 'ORG')
# ('States', 'GPE')
# ('Senate', 'ORG')
# ('Departments', 'PERSON')
# ('Subject', 'PERSON')
# ('Senate', 'ORG')
# ('Senate', 'ORG')
# ('House', 'ORG')
# ('Reprieves', 'PERSON')
# ('Certificates', 'PRODUCT')
# ('Votes', 'NORP')
# ('the United States', 'GPE')
# ('Cases of Impeachment', 'ORG')
# ('2He', 'CARDINAL')
# ('Advice', 'ORG')
# ('Senate', 'ORG')
# ('more provided two thirds', 'CARDINAL')
# ('the House of Rep-', 'ORG')
# ('Senate', 'ORG')
# ('Ballot Ambassadors', 'ORG')
# ('Ministers', 'PRODUCT')
# ('one', 'CARDINAL')
# ('the supreme Court', 'ORG')
# ('five', 'CARDINAL')
# ('the Officers of the United States', 'WORK_OF_ART')
# ('Appoint- List', 'PERSON')
# ('House', 'ORG')
# ('Manner', 'PERSON')
# ('Law', 'PERSON')
# ('States', 'GPE')
# ('Representa-', 'PERSON')
# ('Law', 'PERSON')
# ('State', 'ORG')
# ('one', 'CARDINAL')
# ('the Courts of Law', 'ORG')
# ('two thirds', 'CARDINAL')
# ('3The', 'CARDINAL')
# ('Choice', 'ORG')
# ('the Choice of the Vacancies', 'ORG')
# ('Recess', 'ORG')
# ('Senate', 'ORG')
# ('Commissions', 'ORG')
# ('Votes of the Electors', 'ORG')
# ('two', 'CARDINAL')
# ('3.', 'CARDINAL')
# ('Votes', 'ORG')
# ('Senate', 'ORG')
# ('the Congress Information of the State of the chuse', 'ORG')
# ('Consideration 4The Congress', 'ORG')
# ('Measures', 'PERSON')
# ('Occasions', 'PERSON')
# ('Votes', 'ORG')
# ('Houses', 'ORG')
# ('the United States', 'GPE')
# ('5No', 'CARDINAL')
# ('Citizen', 'ORG')
# ('the Time of Adjournment', 'ORG')
# ('the United States', 'GPE')
# ('Time', 'ORG')
# ('Constitution', 'LAW')
# ('the Office of President', 'ORG')
# ('Laws', 'PRODUCT')
# ('Office', 'ORG')
# ('Commission', 'ORG')
# ('the United States', 'GPE')
# ('fourteen Years', 'DATE')
# ('4.', 'CARDINAL')
# ('United States', 'GPE')
# ('the United States', 'GPE')
# ('6In Case', 'MONEY')
# ('Office on Impeachment', 'ORG')
# ('Death, Resignation', 'WORK_OF_ART')
# ('Inability Conviction of', 'ORG')
# ('Treason', 'PERSON')
# ('Bribery', 'ORG')
# ('Crimes and Misdemeanors', 'ORG')
# ('Congress', 'ORG')
# ('Law', 'PERSON')
# ('ARTICLE', 'LAW')
# ('the Case of Removal, Death, Resignation', 'ORG')
# ('1.', 'CARDINAL')
# ('the United Inability', 'ORG')
# ('Presi- States', 'GPE')
# ('one', 'CARDINAL')
# ('Congress', 'ORG')
# ('Disability', 'ORG')
# ('Behaviour', 'GPE')
# ('Times', 'ORG')
# ('Times', 'ORG')
# ('Continuance in Office', 'ORG')
# ('2', 'CARDINAL')
# ('1The', 'CARDINAL')
# ('Cases', 'WORK_OF_ART')
# ('Law and Equity', 'ORG')
# ('the United States', 'GPE')
# ('Constitution', 'LAW')
# ('the Laws of the United States', 'WORK_OF_ART')
# ('Ministers', 'PRODUCT')
# ('the Office of President', 'ORG')
# ('the United States', 'GPE')
# ('the United Ability', 'ORG')
# ('the United States', 'GPE')
# ('two', 'CARDINAL')
# ('State', 'ORG')
# ('2', 'CARDINAL')
# ('1The', 'CARDINAL')
# ('Citizens', 'ORG')
# ('Army', 'ORG')
# ('Navy', 'ORG')
# ('States,—between Citizens of the same State', 'WORK_OF_ART')
# ('Lands', 'GPE')
# ('XII', 'ORG')
# ('XXV', 'ORG')
# ('10This', 'CARDINAL')
# ('State', 'ORG')
# ('the Citizens SECTION', 'LAW')
# ('4', 'CARDINAL')
# ('The United States', 'GPE')
# ('Citizens or Subjects', 'ORG')
# ('State', 'ORG')
# ('Republican', 'NORP')
# ('Ministers and Consuls', 'WORK_OF_ART')
# ('Invasion', 'PRODUCT')
# ('State', 'ORG')
# ('Party', 'ORG')
# ('the supreme Court', 'ORG')
# ('Jurisdiction', 'PERSON')
# ('the supreme Court', 'ORG')
# ('Jurisdiction', 'PERSON')
# ('Law', 'PERSON')
# ('ARTICLE', 'ORG')
# ('Congress', 'ORG')
# ('Congress', 'ORG')
# ('two thirds', 'CARDINAL')
# ('3The', 'CARDINAL')
# ('Cases of Houses', 'WORK_OF_ART')
# ('Impeachment', 'ORG')
# ('Trial Amendments', 'ORG')
# ('Constitution', 'LAW')
# ('State', 'ORG')
# ('the Legislatures of two thirds', 'ORG')
# ('States', 'GPE')
# ('State', 'ORG')
# ('Amendments', 'ORG')
# ('Case', 'PERSON')
# ('Congress', 'ORG')
# ('Intents', 'NORP')
# ('Law', 'PERSON')
# ('Constitution', 'LAW')
# ('3. 1Treason', 'CARDINAL')
# ('three', 'CARDINAL')
# ('States', 'GPE')
# ('States', 'GPE')
# ('War', 'EVENT')
# ('three fourths', 'DATE')
# ('Enemies', 'ORG')
# ('one', 'CARDINAL')
# ('Ratification', 'GPE')
# ('Congress', 'ORG')
# ('Treason', 'ORG')
# ('the Testimony of Amendment', 'WORK_OF_ART')
# ('two', 'CARDINAL')
# ('Witnesses', 'GPE')
# ('Court', 'ORG')
# ('Manner', 'PERSON')
# ('first', 'ORDINAL')
# ('fourth', 'ORDINAL')
# ('2The', 'DATE')
# ('Congress', 'ORG')
# ('Clauses', 'FAC')
# ('first', 'ORDINAL')
# ('Article', 'WORK_OF_ART')
# ('State', 'ORG')
# ('Consent', 'PRODUCT')
# ('Treason', 'PERSON')
# ('Corruption of Blood', 'WORK_OF_ART')
# ('Suffrage', 'PERSON')
# ('Senate', 'ORG')
# ('the Life of the Person', 'WORK_OF_ART')
# ('ARTICLE', 'ORG')
# ('1All', 'CARDINAL')
# ('1', 'CARDINAL')
# ('Full Faith', 'PERSON')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('Constitution', 'LAW')
# ('Confed-', 'PERSON')
# ('State', 'ORG')
# ('Congress', 'ORG')
# ('Constitution', 'LAW')
# ('the Laws of the the Manner', 'WORK_OF_ART')
# ('United States', 'GPE')
# ('Pursuance Proceedings', 'ORG')
# ('the Authority of the United States', 'ORG')
# ('2', 'CARDINAL')
# ('1The Citizens', 'WORK_OF_ART')
# ('State', 'ORG')
# ('Immunities of Judges', 'ORG')
# ('State', 'ORG')
# ('Citizens', 'PERSON')
# ('States', 'GPE')
# ('2A', 'CARDINAL')
# ('State', 'ORG')
# ('Treason', 'PERSON')
# ('Felony', 'ORG')
# ('State', 'ORG')
# ('Contrary', 'LOC')
# ('3The', 'CARDINAL')
# ('State', 'ORG')
# ('De-', 'ORG')
# ('Authority of the State State Legislatures', 'ORG')
# ('Officers', 'WORK_OF_ART')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('Jurisdiction', 'PERSON')
# ('States', 'GPE')
# ('3No Person', 'PERSON')
# ('Labour', 'ORG')
# ('one', 'CARDINAL')
# ('Constitution', 'LAW')
# ('State', 'ORG')
# ('Laws', 'PRODUCT')
# ('Consequence', 'GPE')
# ('Law', 'PERSON')
# ('Office', 'ORG')
# ('United States', 'GPE')
# ('Labour', 'ORG')
# ('ARTICLE', 'LAW')
# ('Party', 'ORG')
# ('Labour', 'ORG')
# ('The Ratification of the Conventions of nine SECTION', 'WORK_OF_ART')
# ('3', 'CARDINAL')
# ('States', 'GPE')
# ('Congress', 'ORG')
# ('Jurisdic-', 'PERSON')
# ('State', 'ORG')
# ('DONE', 'ORG')
# ('Convention', 'ORG')
# ('States', 'GPE')
# ('the Seventeenth Day', 'DATE')
# ('States', 'GPE')
# ('September', 'DATE')
# ('seven hundred and Eighty seven', 'CARDINAL')
# ('Congress', 'ORG')
# ('the Independence of the United States of', 'ORG')
# ('2The', 'CARDINAL')
# ('Congress', 'ORG')
# ('America', 'GPE')
# ('Twelfth', 'NORP')
# ('Rules and Regulations', 'WORK_OF_ART')
# ('Names', 'ORG')
# ('Territory', 'ORG')
# ('GO', 'GPE')
# ('WASHINGTON', 'GPE')
# ('the United States', 'GPE')
# ('Constitution', 'LAW')
# ('Preju-', 'PERSON')
# ('Virginia', 'GPE')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('twelve', 'CARDINAL')
# ('New Hampshire', 'GPE')
# ('THE UNITED STATES OF AMERICA—1787 Page VI NICHOLASGILMAN', 'ORG')
# ('Massachusetts Congress', 'ORG')
# ('Connecticut', 'GPE')
# ('JOHNSON', 'PERSON')
# ('ROGERSHERMAN New York', 'ORG')
# ('II', 'CARDINAL')
# ('State', 'ORG')
# ('New Jersey', 'GPE')
# ('WIL', 'ORG')
# ('Pennsylvania', 'GPE')
# ('Owner', 'ORG')
# ('FRANKLIN', 'ORG')
# ('THOMASMIFFLIN', 'ORG')
# ('ROBTMORRIS GEO', 'PRODUCT')
# ('ARTICLE', 'WORK_OF_ART')
# ('JAREDINGERSOLL', 'PERSON')
# ('JAMESWILSON', 'PERSON')
# ('Delaware', 'GPE')
# ('GEO', 'ORG')
# ('JOHNDICKINSON', 'PRODUCT')
# ('Maryland', 'GPE')
# ('JAMESMCHENRY', 'PERSON')
# ('Virginia', 'GPE')
# ('JOHNBLAIR', 'PERSON')
# ('North Carolina', 'GPE')
# ('South Carolina', 'GPE')
# ('J. RUTLEDGE', 'PERSON')
# ('State', 'ORG')
# ('PIERCEBUTLER', 'ORG')
# ('Georgia', 'GPE')
# ('the Assistance of Counsel', 'WORK_OF_ART')
# ('ADDITION', 'GPE')
# ('States', 'GPE')
# ('UNITED STATES OF AMERICA', 'ORG')
# ('PROPOSED', 'ORG')
# ('Governors', 'PERSON')
# ('Congress', 'ORG')
# ('New Jersey', 'GPE')
# ('November 20, 1789', 'DATE')
# ('CONGRESS', 'ORG')
# ('December 19, 1789', 'DATE')
# ('North Carolina', 'GPE')
# ('December 22, 1789', 'DATE')
# ('South LEGISLATURES', 'LOC')
# ('January 19, 1790', 'DATE')
# ('New Hampshire', 'GPE')
# ('January 25, 1790', 'DATE')
# ('PURSUANT', 'ORG')
# ('FIFTH', 'ORDINAL')
# ('Delaware', 'GPE')
# ('January 28, 1790', 'DATE')
# ('New York', 'GPE')
# ('February 24, 1790', 'DATE')
# ('Penn- sylvania', 'GPE')
# ('March 10, 1790', 'DATE')
# ('Rhode Island', 'GPE')
# ('June 7, 1790', 'DATE')
# ('Vermont', 'GPE')
# ('ORIGINAL', 'ORG')
# ('November 3, 1791', 'DATE')
# ('Virginia', 'GPE')
# ('December 15, 1791', 'DATE')
# ('December 15, 1791', 'DATE')
# ('first', 'ORDINAL')
# ('ten', 'CARDINAL')
# ('the Constitution of the United', 'LAW')
# ('States', 'GPE')
# ('two', 'CARDINAL')
# ('one', 'CARDINAL')
# ('Massachusetts', 'GPE')
# ('March 2, 1939', 'DATE')
# ('Georgia', 'GPE')
# ('March 18, 1939', 'DATE')
# ('Connecticut', 'GPE')
# ('April 19, 1939', 'DATE')
# ('States', 'GPE')
# ('First', 'ORDINAL')
# ('13Only the 13th, 14th, 15th', 'DATE')
# ('16th', 'ORDINAL')
# ('September 25, 1789', 'DATE')
# ('first', 'ORDINAL')
# ('ten', 'CARDINAL')
# ('THE UNITED STATES OF AMERICA—1787', 'ORG')
# ('Suits', 'PERSON')
# ('twenty dollars', 'MONEY')
# ('three', 'CARDINAL')
# ('the House of Representa-', 'ORG')
# ('Court of the United States', 'ORG')
# ('ARTICLE', 'LAW')
# ('VIII', 'ORG')
# ('one', 'CARDINAL')
# ('two-thirds', 'CARDINAL')
# ('the House of Representatives', 'ORG')
# ('ARTICLE [IX', 'LAW')
# ('Constitution', 'LAW')
# ('fourth day of March', 'DATE')
# ('ARTICLE', 'LAW')
# ('the United States', 'GPE')
# ('Constitution', 'LAW')
# ('States', 'GPE')
# ('two', 'CARDINAL')
# ('Senate', 'ORG')
# ('ARTICLE XI', 'LAW')
# ('two- thirds', 'CARDINAL')
# ('Judicial', 'ORG')
# ('the United States', 'GPE')
# ('one', 'CARDINAL')
# ('the United States', 'GPE')
# ('Citizens', 'PERSON')
# ('State', 'ORG')
# ('Citizens or Subjects', 'ORG')
# ('eleventh', 'ORDINAL')
# ('the Constitution of the The twelfth', 'LAW')
# ('the Constitution of the United States', 'LAW')
# ('the United States', 'GPE')
# ('States', 'GPE')
# ('Third', 'ORDINAL')
# ('Congress', 'ORG')
# ('4th', 'ORDINAL')
# ('the Eighth Congress', 'ORG')
# ('the 9th of March 1794', 'DATE')
# ('December, 1803', 'DATE')
# ('third', 'ORDINAL')
# ('Congress', 'ORG')
# ('the 8th of January, 1798', 'DATE')
# ('first', 'ORDINAL')
# ('second', 'ORDINAL')
# ('State', 'ORG')
# ('the 25th of September, 1804', 'DATE')
# ('New York', 'GPE')
# ('March 27, 1794', 'DATE')
# ('Rhode Island', 'GPE')
# ('March 31, 1794', 'DATE')
# ('13', 'CARDINAL')
# ('17', 'CARDINAL')
# ('Connecticut', 'GPE')
# ('May 8, 1794', 'DATE')
# ('New Hampshire', 'GPE')
# ('June 16, 1794', 'DATE')
# ('North Carolina', 'GPE')
# ('December 21, 1803', 'DATE')
# ('Massachusetts', 'GPE')
# ('June 26, 1794', 'DATE')
# ('Vermont', 'GPE')
# ('Maryland', 'GPE')
# ('December 24, 1803', 'DATE')
# ('Kentucky', 'GPE')
# ('December 27', 'DATE')
# ('9, 1794', 'DATE')
# ('November 9, 1794', 'DATE')
# ('Virginia', 'GPE')
# ('November 18, 1803', 'DATE')
# ('Ohio', 'GPE')
# ('December 30, 1803', 'DATE')
# ('Pennsylvania', 'GPE')
# ('January 5, 1794', 'DATE')
# ('Georgia', 'GPE')
# ('November 29, 1794', 'DATE')
# ('Kentucky', 'GPE')
# ('December 1804', 'DATE')
# ('Vermont', 'GPE')
# ('January 30, 1804', 'DATE')
# ('Virginia', 'GPE')
# ('February 3', 'DATE')
# ('7, 1794', 'DATE')
# ('Maryland', 'GPE')
# ('December 26, 1794', 'DATE')
# ('Delaware', 'GPE')
# ('January 1804', 'DATE')
# ('New York', 'GPE')
# ('February 10, 1804', 'DATE')
# ('New Jersey', 'GPE')
# ('23, 1795', 'DATE')
# ('North Carolina', 'GPE')
# ('February 7, 1795', 'DATE')
# ('22, 1804', 'DATE')
# ('Rhode Island', 'GPE')
# ('March 12, 1804', 'DATE')
# ('South', 'LOC')
# ('February 7, 1795', 'DATE')
# ('lina', 'ORG')
# ('May 15, 1804', 'DATE')
# ('Georgia', 'GPE')
# ('May 19, 1804', 'DATE')
# ('South', 'LOC')
# ('June 15, 1804', 'DATE')
# ('Carolina', 'GPE')
# ('December 4, 1797', 'DATE')
# ('New Jersey', 'GPE')
# ('Pennsyl- Ratification', 'ORG')
# ('June 15, 1804', 'DATE')
# ('vania', 'PERSON')
# ('ARTICLE XII', 'PRODUCT')
# ('July 27, 1804', 'DATE')
# ('Delaware', 'GPE')
# ('January', 'DATE')
# ('18, 1804', 'DATE')
# ('Massachusetts', 'GPE')
# ('February 3, 1804', 'DATE')
# ('Connecticut', 'GPE')
# ('May 10, 1804', 'DATE')
# ('one', 'CARDINAL')
# ('ARTICLE XIII', 'FAC')
# ('the United States', 'GPE')
# ('Congress', 'ORG')
# ('the United States', 'GPE')
# ('thirteenth', 'ORDINAL')
# ('the Constitution of the President of the Senate;—The', 'LAW')
# ('the United States', 'GPE')
# ('Senate', 'ORG')
# ('Senate', 'ORG')
# ('States', 'GPE')
# ('Congress', 'ORG')
# ('the House of Representatives', 'ORG')
# ('all the certifi- 31st day of January, 1865', 'DATE')
# ('section 3', 'LAW')
# ('XX', 'GPE')
# ('THE UNITED STATES OF AMERICA—1787 Page', 'ORG')
# ('State', 'ORG')
# ('the 18th', 'DATE')
# ('1865', 'DATE')
# ('Congress', 'ORG')
# ('two-thirds', 'CARDINAL')
# ('twenty-seven', 'CARDINAL')
# ('House', 'ORG')
# ('Illinois', 'GPE')
# ('February 1, 1865', 'DATE')
# ('Rhode', 'PERSON')
# ('February 2, 1865', 'DATE')
# ('Michigan', 'GPE')
# ('February 2, 1865', 'DATE')
# ('the United States', 'GPE')
# ('Maryland', 'GPE')
# ('February 3, 1865', 'DATE')
# ('New York', 'GPE')
# ('February 3, 1865', 'DATE')
# ('Pennsylvania', 'GPE')
# ('February 3, 1865', 'DATE')
# ('West Virginia', 'GPE')
# ('3', 'CARDINAL')
# ('1865', 'DATE')
# ('Missouri', 'GPE')
# ('February 6, 1865', 'DATE')
# ('Maine', 'GPE')
# ('7', 'CARDINAL')
# ('1865', 'DATE')
# ('Kansas', 'GPE')
# ('February 7, 1865', 'DATE')
# ('Massachusetts', 'GPE')
# ('February 7, 1865', 'DATE')
# ('Virginia', 'GPE')
# ('February 9, 1865', 'DATE')
# ('Ohio', 'GPE')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('10, 1865', 'DATE')
# ('Indiana', 'GPE')
# ('February 13, 1865', 'DATE')
# ('Nevada', 'GPE')
# ('16, 1865', 'DATE')
# ('Louisiana', 'GPE')
# ('February 17, 1865', 'DATE')
# ('Minnesota', 'GPE')
# ('the United February 23, 1865', 'GPE')
# ('Wisconsin', 'GPE')
# ('February 24, 1865', 'DATE')
# ('March 9, 1865', 'DATE')
# ('Tennessee', 'GPE')
# ('April 7, 1865', 'DATE')
# ('Arkansas', 'GPE')
# ('April 14, 1865', 'DATE')
# ('Connecticut', 'GPE')
# ('May 4, 1865', 'DATE')
# ('New Hampshire', 'GPE')
# ('July 1, 1865', 'DATE')
# ('South Carolina', 'GPE')
# ('November 13, 1865', 'DATE')
# ('December 2, 1865', 'DATE')
# ('North Carolina', 'GPE')
# ('December 4', 'DATE')
# ('Congress', 'ORG')
# ('1865', 'DATE')
# ('Georgia', 'GPE')
# ('December 6, 1865', 'DATE')
# ('Ratification', 'PRODUCT')
# ('December 6, 1865', 'DATE')
# ('Oregon', 'GPE')
# ('December 8, 1865', 'DATE')
# ('California', 'GPE')
# ('December 19, 1865', 'DATE')
# ('Florida', 'GPE')
# ('December 28, 1865', 'DATE')
# ('Florida', 'GPE')
# ('June 9', 'DATE')
# ('the Constitution of the', 'LAW')
# ('1868', 'DATE')
# ('Iowa', 'GPE')
# ('United States', 'GPE')
# ('the January 15, 1866', 'DATE')
# ('New Jersey', 'GPE')
# ('January 23, 1866', 'DATE')
# ('States', 'GPE')
# ('Thirty-ninth', 'DATE')
# ('Congress', 'ORG')
# ('March 16, 1865', 'DATE')
# ('13th of June, 1866', 'DATE')
# ('Texas', 'GPE')
# ('February 18, 1870', 'DATE')
# ('Delaware', 'GPE')
# ('February 12, 1901', 'DATE')
# ('State', 'ORG')
# ('July 28, 1868', 'DATE')
# ('February 8', 'DATE')
# ('28', 'CARDINAL')
# ('1865', 'DATE')
# ('Kentucky', 'GPE')
# ('March 18, 1976', 'DATE')
# ('Connecticut', 'GPE')
# ('June 25, 1866', 'DATE')
# ('February 24, 1865', 'DATE')
# ('Mississippi', 'GPE')
# ('March 16, 1995 (', 'DATE')
# ('New Hampshire', 'GPE')
# ('July 6, 1866', 'DATE')
# ('Tennessee', 'GPE')
# ('July 19, 1866', 'DATE')
# ('December 4, 1865', 'DATE')
# ('New Jersey', 'GPE')
# ('September 11, 1866', 'DATE')
# ('ARTICLE XIV', 'PRODUCT')
# ('March 24, 1868', 'DATE')
# ('Nov. 12, 1980', 'DATE')
# ('the United States', 'GPE')
# ('Oregon', 'GPE')
# ('September 19, 1866', 'DATE')
# ('the United States', 'GPE')
# ('October 16, 1868', 'DATE')
# ('State', 'ORG')
# ('April 25, 1973', 'DATE')
# ('Vermont', 'GPE')
# ('30, 1866', 'DATE')
# ('Ohio', 'GPE')
# ('January 11, 1867', 'DATE')
# ('January 15, 1868', 'DATE')
# ('March 12, 2003', 'DATE')
# ('New York', 'GPE')
# ('January 10', 'DATE')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('1867', 'DATE')
# ('Kansas', 'GPE')
# ('January 11, 1867', 'DATE')
# ('Illinois', 'GPE')
# ('January 15, 1867', 'DATE')
# ('West Virginia', 'GPE')
# ('January 16, 1867', 'DATE')
# ('Michigan', 'GPE')
# ('January 16', 'DATE')
# ('1867', 'DATE')
# ('Minnesota', 'GPE')
# ('January 16, 1867', 'DATE')
# ('Maine', 'GPE')
# ('January 19', 'DATE')
# ('1867', 'DATE')
# ('Nevada', 'GPE')
# ('January 22, 1867', 'DATE')
# ('Indiana', 'GPE')
# ('January 23', 'DATE')
# ('1867', 'DATE')
# ('Missouri', 'GPE')
# ('January 25, 1867', 'DATE')
# ('Rhode Island', 'GPE')
# ('February SECTION 2', 'DATE')
# ('7, 1867', 'DATE')
# ('Wisconsin', 'GPE')
# ('February 7, 1867', 'DATE')
# ('Pennsylvania', 'GPE')
# ('12', 'CARDINAL')
# ('1867', 'DATE')
# ('Massachusetts', 'GPE')
# ('March 20, 1867', 'DATE')
# ('Nebraska', 'GPE')
# ('June 15, 1867', 'DATE')
# ('Iowa', 'GPE')
# ('March 16, 1868', 'DATE')
# ('Arkansas', 'GPE')
# ('April 6', 'DATE')
# ('1868', 'DATE')
# ('Florida', 'GPE')
# ('June 9, 1868', 'DATE')
# ('North Carolina', 'GPE')
# ('July 4, 1868', 'DATE')
# ('State', 'ORG')
# ('December 14, 1866', 'DATE')
# ('Louisi-', 'PERSON')
# ('July 9, 1868', 'DATE')
# ('February', 'DATE')
# ('6, 1867', 'DATE')
# ('South Carolina', 'GPE')
# ('July 9, 1868', 'DATE')
# ('the United States', 'GPE')
# ('December 20, 1866', 'DATE')
# ('Congress', 'ORG')
# ('Executive', 'ORG')
# ('Ju- Ratification', 'ORG')
# ('July 9, 1868', 'DATE')
# ('State', 'ORG')
# ('July 13, 1868', 'DATE')
# ('Georgia', 'GPE')
# ('July 21, 1868', 'DATE')
# ('Legislature', 'ORG')
# ('November 9, 1866', 'DATE')
# ('Virginia', 'GPE')
# ('October 8', 'DATE')
# ('State', 'ORG')
# ('twenty-one', 'CARDINAL')
# ('January 9, 1867', 'DATE')
# ('years', 'DATE')
# ('the United States', 'GPE')
# ('January 17, 1870', 'DATE')
# ('Texas', 'GPE')
# ('February 18, 1870', 'DATE')
# ('October 27, 1866', 'DATE')
# ('Delaware', 'GPE')
# ('12', 'CARDINAL')
# ('1901', 'DATE')
# ('February 8', 'DATE')
# ('1867', 'DATE')
# ('Maryland', 'GPE')
# ('April 4, 1959', 'DATE')
# ('March 23, 1867', 'DATE')
# ('California', 'GPE')
# ('May 6, 1959', 'DATE')
# ('Kentucky', 'GPE')
# ('March 18, 1976', 'DATE')
# ('January 8, 1867', 'DATE')
# ('twenty-one years of age', 'DATE')
# ('State', 'ORG')
# ('ARTICLE XV', 'PRODUCT')
# ('Congress', 'ORG')
# ('United', 'ORG')
# ('the United States', 'GPE')
# ('States', 'GPE')
# ('State', 'ORG')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('Congress', 'ORG')
# ('the United States', 'GPE')
# ('2', 'CARDINAL')
# ('Congress', 'ORG')
# ('State', 'ORG')
# ('State', 'ORG')
# ('the United States', 'GPE')
# ('the Constitution of the surrection or', 'LAW')
# ('United States', 'GPE')
# ('States', 'GPE')
# ('26th', 'ORDINAL')
# ('15See', 'CARDINAL')
# ('section 1', 'LAW')
# ('XXVI', 'PERSON')
# ('February, 1869', 'DATE')
# ('Page IX CONSTITUTION', 'ORG')
# ('THE UNITED STATES OF AMERICA—1787', 'ORG')
# ('State', 'ORG')
# ('March 30, 1870', 'DATE')
# ('six years', 'DATE')
# ('twenty-nine', 'CARDINAL')
# ('one', 'CARDINAL')
# ('thirty-seven States', 'PERCENT')
# ('State', 'ORG')
# ('vada', 'GPE')
# ('March 1, 1869', 'DATE')
# ('West Virginia', 'GPE')
# ('March 3, 1869', 'DATE')
# ('March 5, 1869', 'DATE')
# ('Louisiana', 'GPE')
# ('March 5, 1869', 'DATE')
# ('North Carolina', 'GPE')
# ('March 5, 1869', 'DATE')
# ('Michigan', 'GPE')
# ('March 8, 1869', 'DATE')
# ('State', 'ORG')
# ('consin', 'GPE')
# ('March 9, 1869', 'DATE')
# ('Maine', 'GPE')
# ('March 11, 1869', 'DATE')
# ('March 12, 1869', 'DATE')
# ('Arkansas', 'GPE')
# ('March 15, 1869', 'DATE')
# ('South', 'LOC')
# ('State', 'ORG')
# ('Senate', 'ORG')
# ('Carolina', 'GPE')
# ('March 15, 1869', 'DATE')
# ('Pennsylvania', 'GPE')
# ('March 25, 1869', 'DATE')
# ('State', 'ORG')
# ('New York', 'GPE')
# ('April 14, 1869', 'DATE')
# ('State', 'ORG')
# ('January 5, 1870', 'DATE')
# ('State', 'ORG')
# ('March 30, 1970', 'DATE')
# ('Indiana', 'GPE')
# ('May 14, 1869', 'DATE')
# ('Connecticut', 'GPE')
# ('May 19, 1869', 'DATE')
# ('Florida', 'GPE')
# ('June 14, 1869', 'DATE')
# ('New Hampshire', 'GPE')
# ('July 1', 'DATE')
# ('as 1869', 'DATE')
# ('Virginia', 'GPE')
# ('October 8, 1869', 'DATE')
# ('Vermont', 'GPE')
# ('October 20', 'DATE')
# ('1869', 'DATE')
# ('Missouri', 'GPE')
# ('January 7, 1870', 'DATE')
# ('Minnesota', 'GPE')
# ('January 13', 'DATE')
# ('1870', 'DATE')
# ('Mississippi', 'GPE')
# ('January 17, 1870', 'DATE')
# ('Rhode Island', 'GPE')
# ('18, 1870', 'DATE')
# ('Kansas', 'GPE')
# ('January 19, 1870', 'DATE')
# ('Ohio', 'GPE')
# ('January 27', 'DATE')
# ('1870', 'DATE')
# ('April 30, 1869', 'DATE')
# ('Georgia', 'GPE')
# ('February 2, 1870', 'DATE')
# ('Iowa', 'GPE')
# ('February 3, 1870', 'DATE')
# ('February 3, 1870', 'DATE')
# ('New York', 'GPE')
# ('seventeenth', 'ORDINAL')
# ('Constitution', 'LAW')
# ('the United States', 'GPE')
# ('February 17, 1870', 'DATE')
# ('Nebraska', 'GPE')
# ('Texas', 'GPE')
# ('States', 'GPE')
# ('the Sixty-second', 'EVENT')
# ('Congress', 'ORG')
# ('the February 18, 1870', 'DATE')
# ('New Jersey', 'GPE')
# ('February 15, 1871 (after 13th of May, 1912', 'DATE')
# ('February 7, 1870', 'DATE')
# ('Delaware', 'GPE')
# ('State', 'ORG')
# ('the 31st of May, 1913', 'DATE')
# ('12', 'CARDINAL')
# ('1901', 'DATE')
# ('March 18', 'DATE')
# ('36', 'CARDINAL')
# ('48 1869', 'DATE')
# ('Oregon', 'GPE')
# ('February 24, 1959', 'DATE')
# ('California', 'GPE')
# ('April 3, 1962', 'DATE')
# ('Massachusetts', 'GPE')
# ('January 28, 1870', 'DATE')
# ('May 22, 1912', 'DATE')
# ('Arizona', 'GPE')
# ('June 3, 1912', 'DATE')
# ('Minnesota', 'GPE')
# ('June 10', 'DATE')
# ('March 18, 1976', 'DATE')
# ('March 1912', 'DATE')
# ('New York', 'GPE')
# ('January 15, 1913', 'DATE')
# ('Kansas', 'GPE')
# ('January 17', 'DATE')
# ('12, 1869', 'DATE')
# ('Tennessee', 'GPE')
# ('April 2, 1997', 'DATE')
# ('1913', 'DATE')
# ('Oregon', 'GPE')
# ('January 23, 1913', 'DATE')
# ('North Carolina', 'GPE')
# ('January', 'DATE')
# ('November 16, 1869', 'DATE')
# ('25, 1913', 'DATE')
# ('California', 'GPE')
# ('January 28, 1913', 'DATE')
# ('Michigan', 'GPE')
# ('January', 'DATE')
# ('28, 1913', 'DATE')
# ('Iowa', 'GPE')
# ('January 30, 1913', 'DATE')
# ('Montana', 'GPE')
# ('January 30', 'DATE')
# ('Maryland', 'GPE')
# ('May 7, 1973', 'DATE')
# ('Maryland', 'GPE')
# ('1913', 'DATE')
# ('Idaho', 'GPE')
# ('January 31, 1913', 'DATE')
# ('West Virginia', 'GPE')
# ('February 4', 'DATE')
# ('February 26, 1870.', 'DATE')
# ('1913', 'DATE')
# ('Colorado', 'GPE')
# ('February 5, 1913', 'DATE')
# ('Nevada', 'GPE')
# ('February 6, 1913', 'DATE')
# ('Texas', 'GPE')
# ('February 7, 1913', 'DATE')
# ('Washington', 'GPE')
# ('February 7', 'DATE')
# ('ARTICLE XVI', 'LAW')
# ('1913', 'DATE')
# ('Wyoming', 'GPE')
# ('February 8, 1913', 'DATE')
# ('Arkansas', 'GPE')
# ('February 11', 'DATE')
# ('Congress', 'ORG')
# ('1913', 'DATE')
# ('Maine', 'GPE')
# ('February 11, 1913', 'DATE')
# ('Illinois', 'GPE')
# ('February 13, 1913', 'DATE')
# ('North Dakota', 'GPE')
# ('February 14, 1913', 'DATE')
# ('Wisconsin', 'GPE')
# ('18, 1913', 'DATE')
# ('Indiana', 'GPE')
# ('February 19, 1913', 'DATE')
# ('February 19, 1913', 'DATE')
# ('Vermont', 'GPE')
# ('February 19, 1913', 'DATE')
# ('States', 'GPE')
# ('South Dakota', 'GPE')
# ('February 19, 1913', 'DATE')
# ('Oklahoma', 'GPE')
# ('February', 'DATE')
# ('24, 1913', 'DATE')
# ('Ohio', 'GPE')
# ('February 25, 1913', 'DATE')
# ('Missouri', 'GPE')
# ('March 7, 1913', 'DATE')
# ('New Mexico', 'GPE')
# ('March 13, 1913', 'DATE')
# ('Nebraska', 'GPE')
# ('March 14, 1913', 'DATE')
# ('New Jersey', 'GPE')
# ('March 17, 1913', 'DATE')
# ('Tennessee', 'GPE')
# ('April 1, 1913', 'DATE')
# ('The sixteenth', 'DATE')
# ('the Constitution of the Pennsylvania', 'LAW')
# ('April 2, 1913', 'DATE')
# ('Connecticut', 'GPE')
# ('April 8, 1913', 'DATE')
# ('United States', 'GPE')
# ('Ratification', 'GPE')
# ('April 8, 1913', 'DATE')
# ('States', 'GPE')
# ('the Sixty-first', 'EVENT')
# ('Congress', 'ORG')
# ('the 12th', 'DATE')
# ('Louisi-', 'PERSON')
# ('July, 1909', 'DATE')
# ('June 11, 1914', 'DATE')
# ('Alabama', 'GPE')
# ('April 16, 2002', 'DATE')
# ('Delaware', 'GPE')
# ('State', 'ORG')
# ('the 25th of February, 1913', 'DATE')
# ('July 1, 2010', 'DATE')
# ('Maryland', 'GPE')
# ('May 22, 2012', 'DATE')
# ('Rhode Island', 'GPE')
# ('July', 'DATE')
# ('36', 'CARDINAL')
# ('3, 2014', 'DATE')
# ('Alabama', 'GPE')
# ('August 10, 1909', 'DATE')
# ('Kentucky', 'GPE')
# ('Utah', 'GPE')
# ('February 8, 1910', 'DATE')
# ('South Carolina', 'GPE')
# ('February 19, 1910', 'DATE')
# ('February 26, 1913', 'DATE')
# ('nois, March 1, 1910', 'DATE')
# ('Mississippi', 'GPE')
# ('March 7, 1910', 'DATE')
# ('March 10, 1910', 'DATE')
# ('Maryland', 'GPE')
# ('April 8, 1910', 'DATE')
# ('Georgia', 'GPE')
# ('August 3, 1910', 'DATE')
# ('Texas', 'GPE')
# ('August 16, 1910', 'DATE')
# ('Ohio', 'GPE')
# ('January 19, 1911', 'DATE')
# ('Idaho', 'GPE')
# ('January 20, 1911', 'DATE')
# ('Oregon', 'GPE')
# ('January 23, 1911', 'DATE')
# ('one year', 'DATE')
# ('Washington', 'GPE')
# ('January 26, 1911', 'DATE')
# ('Montana', 'GPE')
# ('January 30', 'DATE')
# ('trans- 1911', 'DATE')
# ('Indiana', 'GPE')
# ('January 30, 1911', 'DATE')
# ('California', 'GPE')
# ('January 31', 'DATE')
# ('1911', 'DATE')
# ('Nevada', 'GPE')
# ('January 31, 1911', 'DATE')
# ('South Dakota', 'GPE')
# ('February', 'DATE')
# ('3, 1911', 'DATE')
# ('Nebraska', 'GPE')
# ('February 9, 1911', 'DATE')
# ('North Carolina', 'GPE')
# ('the United States', 'GPE')
# ('11, 1911', 'DATE')
# ('Colorado', 'GPE')
# ('February 15, 1911', 'DATE')
# ('kota', 'GPE')
# ('February 17, 1911', 'DATE')
# ('Kansas', 'GPE')
# ('February 18, 1911', 'DATE')
# ('Michigan', 'GPE')
# ('February 23, 1911', 'DATE')
# ('Iowa', 'GPE')
# ('February 24, 1911', 'DATE')
# ('Missouri', 'GPE')
# ('March 16, 1911', 'DATE')
# ('Maine', 'GPE')
# ('March 31, 1911', 'DATE')
# ('SEC', 'ORG')
# ('2', 'CARDINAL')
# ('Congress', 'ORG')
# ('States', 'GPE')
# ('April 7, 1911', 'DATE')
# ('Arkansas', 'GPE')
# ('April 22, 1911', 'DATE')
# ('Wisconsin', 'GPE')
# ('May 26, 1911', 'DATE')
# ('July 12, 1911', 'DATE')
# ('Arizona', 'GPE')
# ('April 6, 1912', 'DATE')
# ('Minnesota', 'GPE')
# ('SEC', 'ORG')
# ('3', 'CARDINAL')
# ('June 11, 1912', 'DATE')
# ('Louisiana', 'GPE')
# ('June 28, 1912', 'DATE')
# ('West Virginia', 'GPE')
# ('January 31, 1913', 'DATE')
# ('New Mexico', 'GPE')
# ('February 3, 1913', 'DATE')
# ('Constitution', 'LAW')
# ('Ratification', 'GPE')
# ('February 3, 1913', 'DATE')
# ('Massa-', 'PERSON')
# ('States', 'GPE')
# ('Constitution', 'LAW')
# ('chusetts', 'PERSON')
# ('March 4, 1913', 'DATE')
# ('New Hampshire', 'GPE')
# ('March 7, 1913', 'DATE')
# ('seven years', 'DATE')
# ('March 2, 1911', 'DATE')
# ('Congress', 'ORG')
# ('Connecticut', 'GPE')
# ('Rhode Island', 'GPE')
# ('Utah', 'GPE')
# ('eighteenth', 'ORDINAL')
# ('the Constitution of the', 'LAW')
# ('ARTICLE XVII', 'PRODUCT')
# ('United States', 'GPE')
# ('the The Senate of the United States', 'ORG')
# ('two', 'CARDINAL')
# ('State', 'ORG')
# ('16Repealed', 'CARDINAL')
# ('section 1', 'LAW')
# ('THE UNITED STATES OF AMERICA—1787 Page X', 'ORG')
# ('the Sixty-fifth', 'EVENT')
# ('Congress', 'ORG')
# ('the 18th', 'DATE')
# ('8, 1953', 'DATE')
# ('September 22', 'DATE')
# ('December, 1917', 'DATE')
# ('1919', 'DATE')
# ('Florida', 'GPE')
# ('May 13, 1969', 'DATE')
# ('South Carolina', 'GPE')
# ('July 1, 1969', 'DATE')
# ('State', 'ORG')
# ('the 29th of January', 'DATE')
# ('January 28, 1920', 'DATE')
# ('1919', 'DATE')
# ('36', 'CARDINAL')
# ('August 22, 1973', 'DATE')
# ('Georgia', 'GPE')
# ('February 20', 'DATE')
# ('1970', 'DATE')
# ('July 24, 1919', 'DATE')
# ('Louisi-', 'PERSON')
# ('January 8, 1918', 'DATE')
# ('Virginia', 'GPE')
# ('January 11, 1918', 'DATE')
# ('June 11, 1970', 'DATE')
# ('July 1', 'DATE')
# ('Kentucky', 'GPE')
# ('January 14, 1918', 'DATE')
# ('North Dakota', 'GPE')
# ('January 25, 1920', 'DATE')
# ('North Carolina', 'GPE')
# ('May 6, 1971', 'DATE')
# ('Mississippi', 'GPE')
# ('March 1918', 'DATE')
# ('South Carolina', 'GPE')
# ('January 29, 1918', 'DATE')
# ('Maryland', 'GPE')
# ('22, 1984', 'DATE')
# ('March 29, 1920', 'DATE')
# ('13', 'CARDINAL')
# ('1918', 'DATE')
# ('Montana', 'GPE')
# ('February 19, 1918', 'DATE')
# ('Texas', 'GPE')
# ('March 4, 1918', 'DATE')
# ('Delaware', 'GPE')
# ('March 18, 1918', 'DATE')
# ('South Dakota', 'GPE')
# ('ARTICLE', 'ORG')
# ('XX', 'GPE')
# ('March 20, 1918', 'DATE')
# ('Massachusetts', 'GPE')
# ('April 2, 1918', 'DATE')
# ('Arizona', 'GPE')
# ('SECTION1', 'ORG')
# ('May 24, 1918', 'DATE')
# ('Georgia', 'GPE')
# ('June 26, 1918', 'DATE')
# ('Louisiana', 'GPE')
# ('August', 'DATE')
# ('noon', 'TIME')
# ('the 20th day of', 'DATE')
# ('3, 1918', 'DATE')
# ('Florida', 'GPE')
# ('December 3, 1918', 'DATE')
# ('Michigan', 'GPE')
# ('January 2, January', 'DATE')
# ('1919', 'DATE')
# ('Ohio', 'GPE')
# ('January 7, 1919', 'DATE')
# ('Oklahoma', 'GPE')
# ('January 7, 1919', 'DATE')
# ('Idaho', 'GPE')
# ('January 8, 1919', 'DATE')
# ('Maine', 'GPE')
# ('January 8, 1919', 'DATE')
# ('West', 'LOC')
# ('noon', 'TIME')
# ('the 3d day of January', 'DATE')
# ('Virginia', 'GPE')
# ('January 9, 1919', 'DATE')
# ('California', 'GPE')
# ('January 13, 1919', 'DATE')
# ('the years', 'DATE')
# ('Tennessee', 'GPE')
# ('January 13, 1919', 'DATE')
# ('Washington', 'GPE')
# ('January 13', 'DATE')
# ('1919', 'DATE')
# ('Arkansas', 'GPE')
# ('January 14, 1919', 'DATE')
# ('Kansas', 'GPE')
# ('January 14', 'DATE')
# ('1919', 'DATE')
# ('Alabama', 'GPE')
# ('January 15, 1919', 'DATE')
# ('Colorado', 'GPE')
# ('January 15', 'DATE')
# ('SEC', 'ORG')
# ('2', 'CARDINAL')
# ('Congress', 'ORG')
# ('at least 1919', 'CARDINAL')
# ('Iowa', 'GPE')
# ('January 15, 1919', 'DATE')
# ('New Hampshire', 'GPE')
# ('January', 'DATE')
# ('every year', 'DATE')
# ('15, 1919', 'DATE')
# ('Oregon', 'GPE')
# ('January 15, 1919', 'DATE')
# ('Nebraska', 'GPE')
# ('January 16', 'DATE')
# ('noon', 'TIME')
# ('the 3d day of January', 'DATE')
# ('1919', 'DATE')
# ('North Carolina', 'GPE')
# ('January 16, 1919', 'DATE')
# ('Utah', 'GPE')
# ('January', 'DATE')
# ('16, 1919', 'DATE')
# ('Missouri', 'GPE')
# ('January 16, 1919', 'DATE')
# ('Wyoming', 'GPE')
# ('January 16, 1919', 'DATE')
# ('SEC', 'ORG')
# ('3', 'CARDINAL')
# ('Ratification', 'GPE')
# ('January 16, 1919', 'DATE')
# ('Dillon v. Gloss', 'ORG')
# ('256', 'CARDINAL')
# ('U.S. 368', 'ORG')
# ('376', 'CARDINAL')
# ('1921', 'DATE')
# ('January 17, 1919', 'DATE')
# ('Wisconsin', 'GPE')
# ('January 17, 1919', 'DATE')
# ('New Mexico', 'GPE')
# ('January 20, 1919', 'DATE')
# ('Nevada', 'GPE')
# ('January 21, 1919', 'DATE')
# ('New York', 'GPE')
# ('January 29, 1919', 'DATE')
# ('Vermont', 'GPE')
# ('January 29, 1919', 'DATE')
# ('Pennsylvania', 'GPE')
# ('February 25, 1919', 'DATE')
# ('New Jersey', 'GPE')
# ('March 9, 1922', 'DATE')
# ('Congress', 'ORG')
# ('Connecticut', 'GPE')
# ('Rhode Island', 'GPE')
# ('ARTICLE', 'LAW')
# ('the United States', 'GPE')
# ('United States', 'GPE')
# ('State', 'ORG')
# ('Congress', 'ORG')
# ('SEC', 'ORG')
# ('4', 'CARDINAL')
# ('Congress', 'ORG')
# ('PROPOSAL', 'ORG')
# ('the House of Representatives', 'ORG')
# ('nineteenth', 'ORDINAL')
# ('the Constitution of the United States', 'LAW')
# ('States', 'GPE')
# ('the Sixty-sixth', 'EVENT')
# ('Congress', 'ORG')
# ('June, 1919', 'DATE')
# ('State', 'ORG')
# ('the 26th of August', 'DATE')
# ('1920', 'DATE')
# ('36', 'CARDINAL')
# ('SEC', 'ORG')
# ('5', 'CARDINAL')
# ('1', 'CARDINAL')
# ('2', 'CARDINAL')
# ('Illinois', 'GPE')
# ('15th day of', 'DATE')
# ('October', 'DATE')
# ('June 10, 1919', 'DATE')
# ('State', 'ORG')
# ('June 17, 1919', 'DATE')
# ('Michigan', 'GPE')
# ('June 10, 1919', 'DATE')
# ('SEC', 'ORG')
# ('6', 'CARDINAL')
# ('consin', 'GPE')
# ('June 10, 1919', 'DATE')
# ('Kansas', 'GPE')
# ('June 16, 1919', 'DATE')
# ('New York', 'GPE')
# ('June 16, 1919', 'DATE')
# ('Ohio', 'GPE')
# ('June 16, 1919', 'DATE')
# ('Pennsylvania', 'GPE')
# ('June 24, 1919', 'DATE')
# ('Massachusetts', 'GPE')
# ('June 25, 1919', 'DATE')
# ('Texas', 'GPE')
# ('June 28, 1919', 'DATE')
# ('Constitution', 'LAW')
# ('Iowa', 'GPE')
# ('July 2, 1919', 'DATE')
# ('Missouri', 'GPE')
# ('July 3, 1919', 'DATE')
# ('Arkansas', 'GPE')
# ('July fourths', 'DATE')
# ('States', 'GPE')
# ('seven years 28, 1919', 'DATE')
# ('Montana', 'GPE')
# ('August 2, 1919', 'DATE')
# ('Nebraska', 'GPE')
# ('August 2', 'DATE')
# ('1919', 'DATE')
# ('Minnesota', 'GPE')
# ('September 8, 1919', 'DATE')
# ('New Hampshire', 'GPE')
# ('September 10, 1919', 'DATE')
# ('Utah', 'GPE')
# ('October 2, 1919', 'DATE')
# ('California', 'GPE')
# ('November 1, 1919', 'DATE')
# ('Maine', 'GPE')
# ('November 5, 1919', 'DATE')
# ('twentieth', 'ORDINAL')
# ('Constitution', 'LAW')
# ('kota', 'GPE')
# ('December 1, 1919', 'DATE')
# ('South Dakota', 'GPE')
# ('December 4', 'DATE')
# ('1919', 'DATE')
# ('Colorado', 'GPE')
# ('December 15, 1919', 'DATE')
# ('Kentucky', 'GPE')
# ('January 6, Seventy-Second', 'DATE')
# ('the 2d day of March, 1932', 'DATE')
# ('1920', 'DATE')
# ('Rhode Island', 'GPE')
# ('January 6, 1920', 'DATE')
# ('Oregon', 'GPE')
# ('January 13', 'DATE')
# ('1920', 'DATE')
# ('Indiana', 'GPE')
# ('January 16, 1920', 'DATE')
# ('Wyoming', 'GPE')
# ('January 27', 'DATE')
# ('State', 'ORG')
# ('the 6th day of February, 1933', 'DATE')
# ('1920', 'DATE')
# ('Nevada', 'GPE')
# ('February 7, 1920', 'DATE')
# ('New Jersey', 'GPE')
# ('February 9', 'DATE')
# ('36', 'CARDINAL')
# ('1920', 'DATE')
# ('Idaho', 'GPE')
# ('February 11, 1920', 'DATE')
# ('Arizona', 'GPE')
# ('February 12', 'DATE')
# ('Virginia', 'GPE')
# ('March 4, 1932', 'DATE')
# ('1920', 'DATE')
# ('New Mexico', 'GPE')
# ('February 21, 1920', 'DATE')
# ('Oklahoma', 'GPE')
# ('New York', 'GPE')
# ('March 11, 1932', 'DATE')
# ('Mississippi', 'GPE')
# ('March 16, 1932', 'DATE')
# ('28', 'CARDINAL')
# ('1920', 'DATE')
# ('West Virginia', 'GPE')
# ('March 10, 1920', 'DATE')
# ('Arkansas', 'GPE')
# ('March 17, 1932', 'DATE')
# ('Kentucky', 'GPE')
# ('March 17, 1932', 'DATE')
# ('March 22, 1920', 'DATE')
# ('Tennessee', 'GPE')
# ('August 18, 1920', 'DATE')
# ('New Jersey', 'GPE')
# ('March 21, 1932', 'DATE')
# ('South Carolina', 'GPE')
# ('March 25', 'DATE')
# ('Ratification', 'GPE')
# ('August 18, 1920.', 'DATE')
# ('1932', 'DATE')
# ('Michigan', 'GPE')
# ('March 31, 1932', 'DATE')
# ('Maine', 'GPE')
# ('April 1, 1932', 'DATE')
# ('Rhode Island', 'GPE')
# ('April 14, 1932', 'DATE')
# ('Illinois', 'GPE')
# ('April 21, 1932', 'DATE')
# ('September 14, 1920', 'DATE')
# ('State', 'ORG')
# ('June 22, 1932', 'DATE')
# ('West Virginia', 'GPE')
# ('July 30, 1932', 'DATE')
# ('September 21, 1920', 'DATE')
# ('Vermont', 'GPE')
# ('February 8', 'DATE')
# ('sylvania', 'GPE')
# ('August 11, 1932', 'DATE')
# ('Indiana', 'GPE')
# ('August 15, 1932', 'DATE')
# ('1921', 'DATE')
# ('Delaware', 'GPE')
# ('March 6, 1923', 'DATE')
# ('Texas', 'GPE')
# ('September 7, 1932', 'DATE')
# ('Alabama', 'GPE')
# ('September 13, 1932', 'DATE')
# ('June 2, 1920', 'DATE')
# ('Maryland', 'GPE')
# ('March 29, 1941', 'DATE')
# ('California', 'GPE')
# ('January 4, 1933', 'DATE')
# ('North Carolina', 'GPE')
# ('January 5', 'DATE')
# ('February 24, 1920', 'DATE')
# ('1933', 'DATE')
# ('North Dakota', 'GPE')
# ('January 9, 1933', 'DATE')
# ('Minnesota', 'GPE')
# ('February 25, 1958', 'DATE')
# ('Virginia', 'GPE')
# ('February 21, 1952', 'DATE')
# ('12, 1933', 'DATE')
# ('Arizona', 'GPE')
# ('January 13, 1933', 'DATE')
# ('Montana', 'GPE')
# ('February 12, 1920', 'DATE')
# ('Alabama', 'GPE')
# ('13, 1933', 'DATE')
# ('Nebraska', 'GPE')
# ('January 13, 1933', 'DATE')
# ('Oklahoma', 'GPE')
# ('Jan- Page XI CONSTITUTION', 'PERSON')
# ('THE UNITED STATES OF AMERICA—1787', 'ORG')
# ('13', 'CARDINAL')
# ('1933', 'DATE')
# ('Kansas', 'GPE')
# ('January 16, 1933', 'DATE')
# ('Oregon', 'GPE')
# ('January', 'DATE')
# ('16, 1933', 'DATE')
# ('Delaware', 'GPE')
# ('January 19, 1933', 'DATE')
# ('Washington', 'GPE')
# ('19, 1933', 'DATE')
# ('Wyoming', 'GPE')
# ('January 19, 1933', 'DATE')
# ('Iowa', 'GPE')
# ('January', 'DATE')
# ('20, 1933', 'DATE')
# ('South Dakota', 'GPE')
# ('January 20, 1933', 'DATE')
# ('Tennessee', 'GPE')
# ('January 20, 1933', 'DATE')
# ('Idaho', 'GPE')
# ('January 21, 1933', 'DATE')
# ('New Mexico', 'GPE')
# ('January 21, 1933', 'DATE')
# ('Georgia', 'GPE')
# ('January 23, 1933', 'DATE')
# ('Missouri', 'GPE')
# ('SEC', 'ORG')
# ('2', 'CARDINAL')
# ('January 23, 1933', 'DATE')
# ('Ohio', 'GPE')
# ('January 23, 1933', 'DATE')
# ('Utah', 'GPE')
# ('January', 'DATE')
# ('23', 'CARDINAL')
# ('1933', 'DATE')
# ('Constitution', 'LAW')
# ('Ratification', 'GPE')
# ('January 23, 1933', 'DATE')
# ('States', 'GPE')
# ('seven years', 'DATE')
# ('Massa-', 'PERSON')
# ('January 24, 1933', 'DATE')
# ('Wisconsin', 'GPE')
# ('January 24', 'DATE')
# ('Congress', 'ORG')
# ('1933', 'DATE')
# ('Colorado', 'GPE')
# ('January 24, 1933', 'DATE')
# ('Nevada', 'GPE')
# ('January 26, 1933', 'DATE')
# ('Connecticut', 'GPE')
# ('January 27, 1933', 'DATE')
# ('New Hampshire', 'GPE')
# ('January 31, 1933', 'DATE')
# ('Vermont', 'GPE')
# ('February 2, 1933', 'DATE')
# ('Maryland', 'GPE')
# ('March 24, 1933', 'DATE')
# ('Florida', 'GPE')
# ('April 26, 1933', 'DATE')
# ('States', 'GPE')
# ('the Eightieth Congress', 'ORG')
# ('Mar. 21, 1947', 'DATE')
# ('House', 'ORG')
# ('Joint Res', 'PERSON')
# ('27', 'CARDINAL')
# ('ARTICLE', 'ORG')
# ('the Administrator of General Services', 'ORG')
# ('Mar. 1, 1951', 'DATE')
# ('eighteenth', 'ORDINAL')
# ('36', 'CARDINAL')
# ('48', 'CARDINAL')
# ('the Constitution of the United States', 'LAW')
# ('States', 'GPE')
# ('Maine', 'GPE')
# ('March 31, 1947', 'DATE')
# ('Michigan', 'GPE')
# ('March 31, 1947', 'DATE')
# ('Iowa', 'GPE')
# ('April 1, 1947', 'DATE')
# ('sas', 'ORG')
# ('April 1, 1947', 'DATE')
# ('New Hampshire', 'GPE')
# ('April 1, 1947', 'DATE')
# ('SECTION 2', 'LAW')
# ('April 2, 1947', 'DATE')
# ('Illinois', 'GPE')
# ('April 3, 1947', 'DATE')
# ('Oregon', 'GPE')
# ('April', 'DATE')
# ('State', 'ORG')
# ('the 3, 1947', 'DATE')
# ('Colorado', 'GPE')
# ('April 12, 1947', 'DATE')
# ('California', 'GPE')
# ('April 15', 'DATE')
# ('United States', 'GPE')
# ('1947', 'DATE')
# ('New Jersey', 'GPE')
# ('April 15, 1947', 'DATE')
# ('Vermont', 'GPE')
# ('April 15, 1947', 'DATE')
# ('Ohio', 'GPE')
# ('April 16, 1947', 'DATE')
# ('Wisconsin', 'GPE')
# ('April 16, 1947', 'DATE')
# ('Pennsyl-', 'ORG')
# ('vania', 'PERSON')
# ('April 29, 1947', 'DATE')
# ('Connecticut', 'GPE')
# ('May 21, 1947', 'DATE')
# ('May 22, 1947', 'DATE')
# ('Nebraska', 'GPE')
# ('May 23, 1947', 'DATE')
# ('Virginia', 'GPE')
# ('January 28, 1948', 'DATE')
# ('Mississippi', 'GPE')
# ('February 12, 1948', 'DATE')
# ('New York', 'GPE')
# ('March 9, 1948', 'DATE')
# ('South Dakota', 'GPE')
# ('January 21, 1949', 'DATE')
# ('Constitution', 'LAW')
# ('North Dakota', 'GPE')
# ('February 25, 1949', 'DATE')
# ('Louisiana', 'GPE')
# ('May 17', 'DATE')
# ('States', 'GPE')
# ('Constitution', 'LAW')
# ('1950', 'DATE')
# ('Montana', 'GPE')
# ('January 25, 1951', 'DATE')
# ('Indiana', 'GPE')
# ('January 29', 'DATE')
# ('seven years', 'DATE')
# ('Idaho', 'GPE')
# ('January 30, 1951', 'DATE')
# ('New Mexico', 'GPE')
# ('February 12', 'DATE')
# ('Congress', 'ORG')
# ('1951', 'DATE')
# ('Wyoming', 'GPE')
# ('February 12, 1951', 'DATE')
# ('Arkansas', 'GPE')
# ('February 15, 1951', 'DATE')
# ('Georgia', 'GPE')
# ('February 17, 1951', 'DATE')
# ('Tennessee', 'GPE')
# ('20, 1951', 'DATE')
# ('Texas', 'GPE')
# ('February 22, 1951', 'DATE')
# ('Nevada', 'GPE')
# ('Constitution', 'LAW')
# ('26', 'CARDINAL')
# ('1951', 'DATE')
# ('Utah', 'GPE')
# ('February 26, 1951', 'DATE')
# ('Minnesota', 'GPE')
# ('Seventy-Second', 'DATE')
# ('27, 1951', 'DATE')
# ('Congress', 'ORG')
# ('the 20th day of February, 1933', 'DATE')
# ('February 27, 1951', 'DATE')
# ('State', 'ORG')
# ('North', 'LOC')
# ('the 5th day of December, 1933', 'DATE')
# ('Carolina', 'GPE')
# ('February 28, 1951', 'DATE')
# ('South Carolina', 'GPE')
# ...
# ('Vermont', 'GPE')
# ('September 23, 1933', 'DATE')
# ('Colorado', 'GPE')
# ('September 26, 1933', 'DATE')
# ('Washington', 'GPE')
# ('October', 'DATE')
# ('ARTICLE', 'WORK_OF_ART')
# ('XXIII', 'ORG')
# ('3, 1933', 'DATE')
# ('Minnesota', 'GPE')
# ('October 10, 1933', 'DATE')
# ('Idaho', 'GPE')
# ('October 17, 1933', 'DATE')
# ('Maryland', 'GPE')
# ('October 18, 1933', 'DATE')
# ('Virginia', 'GPE')
# ('October 25', 'DATE')
# ('1933', 'DATE')
# ('New Mexico', 'GPE')
# ('November 2, 1933', 'DATE')
# ('Florida', 'GPE')
# ('November', 'DATE')
# ('the United States', 'GPE')
# ('14, 1933', 'DATE')
# ('Texas', 'GPE')
# ('November 24, 1933', 'DATE')
# ('Kentucky', 'GPE')
# ('November', 'DATE')
# ('Congress', 'ORG')
# ('27, 1933', 'DATE')
# ('Ohio', 'GPE')
# ('December 5, 1933', 'DATE')
# ('Pennsylvania', 'GPE')
# ('1933', 'DATE')
# ('Utah', 'GPE')
# ('December 5, 1933', 'DATE')
# ('December 5, 1933', 'DATE')
# ('Maine', 'GPE')
# ('Representatives', 'ORG')
# ('Congress', 'ORG')
# ('December 6, 1933', 'DATE')
# ('Montana', 'GPE')
# ('August 6, 1934', 'DATE')
# ('State', 'ORG')
# ('South Carolina', 'GPE')
# ('December 4, 1933', 'DATE')
# ('ARTICLE', 'LAW')
# ('XXII', 'ORG')
# ('States', 'GPE')
# ('State', 'ORG')
# ('more than two years', 'DATE')
# ('twelfth', 'ORDINAL')
# ('SEC', 'ORG')
# ('2', 'CARDINAL')
# ('Congress', 'ORG')
# ('Article shall', 'LAW')
# ('PROPOSAL', 'ORG')
# ('Article', 'LAW')
# ('Eighty-sixth', 'DATE')
# ('Congress', 'ORG')
# ('Congress', 'ORG')
# ('June 17, 1960', 'DATE')
# ('General Services', 'ORG')
# ('Apr. 3, 1961', 'DATE')
# ('THE UNITED STATES OF AMERICA—1787', 'ORG')
# ('38', 'CARDINAL')
# ('50', 'CARDINAL')
# ('States', 'GPE')
# ('Ratification', 'GPE')
# ('January 23, 1964', 'DATE')
# ('Hawaii', 'GPE')
# ('June 23, 1960', 'DATE')
# ('State', 'ORG')
# ('June 30', 'DATE')
# ('February 25, 1977', 'DATE')
# ('North Carolina', 'GPE')
# ('May 3, 1989', 'DATE')
# ('1960', 'DATE')
# ('Massachusetts', 'GPE')
# ('August 22, 1960', 'DATE')
# ('New Jersey', 'GPE')
# ('Texas', 'GPE')
# ('May 22, 2009', 'DATE')
# ('cember 19, 1960', 'DATE')
# ('New York', 'GPE')
# ('January 17, 1961', 'DATE')
# ('California', 'GPE')
# ('Mississippi', 'GPE')
# ('January 19, 1961', 'DATE')
# ('Oregon', 'GPE')
# ('January 27, 1961', 'DATE')
# ('Maryland', 'GPE')
# ('December 20, 1962', 'DATE')
# ('January 30, 1961', 'DATE')
# ('Idaho', 'GPE')
# ('January 31, 1961', 'DATE')
# ('Maine', 'GPE')
# ('31, 1961', 'DATE')
# ('Minnesota', 'GPE')
# ('January 31, 1961', 'DATE')
# ('New Mexico', 'GPE')
# ('February 1, 1961', 'DATE')
# ('Nevada', 'GPE')
# ('February 2, 1961', 'DATE')
# ('Montana', 'GPE')
# ('February 6, 1961', 'DATE')
# ('South Dakota', 'GPE')
# ('February 6, 1961', 'DATE')
# ('General Services', 'ORG')
# ('Feb. 5, 1964', 'DATE')
# ('F.R. Doc. rado', 'PERSON')
# ('February 8, 1961', 'DATE')
# ('Washington', 'GPE')
# ('February 9, 1961', 'DATE')
# ('64–1229', 'CARDINAL')
# ('29', 'CARDINAL')
# ('F.R. 1715', 'DATE')
# ('West Virginia', 'GPE')
# ('February 9, 1961', 'DATE')
# ('Alaska', 'GPE')
# ('February 10, 1961', 'DATE')
# ('Wyoming', 'GPE')
# ('February 13, 1961', 'DATE')
# ('Delaware', 'GPE')
# ('February', 'DATE')
# ('XXV', 'ORG')
# ('20, 1961', 'DATE')
# ('Utah', 'GPE')
# ('February 21, 1961', 'DATE')
# ('Wisconsin', 'GPE')
# ('February 21, 1961', 'DATE')
# ('Pennsylvania', 'GPE')
# ('February 28, 1961', 'DATE')
# ('Indiana', 'GPE')
# ('March 3, 1961', 'DATE')
# ('North Dakota', 'GPE')
# ('March 3, 1961', 'DATE')
# ('Tennessee', 'GPE')
# ('March 6, 1961', 'DATE')
# ('Michigan', 'GPE')
# ('March 8, 1961', 'DATE')
# ('Connecticut', 'GPE')
# ('March 9, 1961', 'DATE')
# ('Arizona', 'GPE')
# ('March 10, 1961', 'DATE')
# ('Illinois', 'GPE')
# ('2', 'CARDINAL')
# ('14, 1961', 'DATE')
# ('Nebraska', 'GPE')
# ('March 15, 1961', 'DATE')
# ('Vermont', 'GPE')
# ('March 15', 'DATE')
# ('1961', 'DATE')
# ('Iowa', 'GPE')
# ('March 16, 1961', 'DATE')
# ('Missouri', 'GPE')
# ('March 20, 1961', 'DATE')
# ('Oklahoma', 'GPE')
# ('March 21, 1961', 'DATE')
# ('Rhode Island', 'GPE')
# ('March 22, 1961', 'DATE')
# ('Kansas', 'GPE')
# ('March 29, 1961', 'DATE')
# ('Ohio', 'GPE')
# ('March 29, 1961', 'DATE')
# ('Congress', 'ORG')
# ('March 29, 1961', 'DATE')
# ('New SEC', 'GPE')
# ('3', 'CARDINAL')
# ('Hampshire', 'PERSON')
# ('March 30, 1961', 'DATE')
# ('State', 'ORG')
# ('Senate', 'ORG')
# ('March 29, 1961', 'DATE')
# ('the House of Representatives', 'ORG')
# ('Alabama', 'GPE')
# ('April 16, 2002', 'DATE')
# ('Arkansas', 'GPE')
# ('January 24, 1961', 'DATE')
# ('General Services', 'ORG')
# ('SEC', 'ORG')
# ('4.', 'CARDINAL')
# ('Apr. 3, 1961', 'DATE')
# ('F.R. Doc', 'PERSON')
# ('26', 'CARDINAL')
# ('2808', 'DATE')
# ('ARTICLE', 'LAW')
# ('Senate', 'ORG')
# ('the United of the House of Representatives', 'GPE')
# ('States', 'GPE')
# ('Congress', 'ORG')
# ('the United States', 'GPE')
# ('State', 'ORG')
# ('Senate', 'ORG')
# ('SEC', 'ORG')
# ('2', 'CARDINAL')
# ('Congress', 'ORG')
# ('the House of Representatives', 'ORG')
# ('Eighty-seventh', 'DATE')
# ('Congress', 'ORG')
# ('29', 'CARDINAL')
# ('Congress', 'ORG')
# ('Senate', 'ORG')
# ('Mar. 27, 1962', 'DATE')
# ('four days', 'DATE')
# ('House of Representatives', 'ORG')
# ('Aug. 27, 1962', 'DATE')
# ('Senate', 'ORG')
# ('the Administrator of General Services', 'ORG')
# ('the House of Representatives', 'ORG')
# ('Feb. 4, 1964', 'DATE')
# ('38', 'CARDINAL')
# ('50', 'CARDINAL')
# ('States', 'GPE')
# ('Thereupon Congress', 'ORG')
# ('the Illinois,', 'LOC')
# ('November 14, 1962', 'DATE')
# ('New Jersey', 'GPE')
# ('December 3', 'DATE')
# ('forty-eight hours', 'TIME')
# ('1962', 'DATE')
# ('Oregon', 'GPE')
# ('January 25, 1963', 'DATE')
# ('Montana', 'GPE')
# ('January 28', 'DATE')
# ('Congress', 'ORG')
# ('1963', 'DATE')
# ('West Virginia', 'GPE')
# ('February 1, 1963', 'DATE')
# ('New York', 'GPE')
# ('4', 'CARDINAL')
# ('1963', 'DATE')
# ('Maryland', 'GPE')
# ('February 6, 1963', 'DATE')
# ('California', 'GPE')
# ('twenty-one days', 'DATE')
# ('the lat- February 7, 1963', 'DATE')
# ('Alaska', 'GPE')
# ('February 11, 1963', 'DATE')
# ('Rhode', 'PERSON')
# ('Congress', 'ORG')
# ('February 14, 1963', 'DATE')
# ('Indiana', 'GPE')
# ('February 19, 1963', 'DATE')
# ('twenty-one days', 'DATE')
# ('Congress Utah', 'ORG')
# ('February 20, 1963', 'DATE')
# ('Michigan', 'GPE')
# ('February 20, 1963', 'DATE')
# ('Colorado', 'GPE')
# ('February 21, 1963', 'DATE')
# ('Ohio', 'GPE')
# ('February 27, 1963', 'DATE')
# ('thirds', 'CARDINAL')
# ('Houses', 'ORG')
# ('Minnesota', 'GPE')
# ('February 27, 1963', 'DATE')
# ('New Mexico', 'GPE')
# ('March 5', 'DATE')
# ('1963', 'DATE')
# ('Hawaii', 'GPE')
# ('March 6, 1963', 'DATE')
# ('North Dakota', 'GPE')
# ('March 7', 'DATE')
# ('1963', 'DATE')
# ('Idaho', 'GPE')
# ('March 8, 1963', 'DATE')
# ('Washington', 'GPE')
# ('March 14, 1963', 'DATE')
# ('Vermont', 'GPE')
# ('March 15, 1963', 'DATE')
# ('Nevada', 'GPE')
# ('March 19, 1963', 'DATE')
# ('March 20, 1963', 'DATE')
# ('Tennessee', 'GPE')
# ('March 21, 1963', 'DATE')
# ('Pennsylvania', 'GPE')
# ('March 25, 1963', 'DATE')
# ('Wisconsin', 'GPE')
# ('March 26, 1963', 'DATE')
# ('Kansas', 'GPE')
# ('March 28, 1963', 'DATE')
# ('Massachusetts', 'GPE')
# ('March 28, 1963', 'DATE')
# ('Nebraska', 'GPE')
# ('April 4, 1963', 'DATE')
# ('Florida', 'GPE')
# ('April 18, 1963', 'DATE')
# ('Iowa', 'GPE')
# ('Eighty-ninth', 'DATE')
# ('24, 1963', 'DATE')
# ('Delaware', 'GPE')
# ('May 1, 1963', 'DATE')
# ('Missouri', 'GPE')
# ('May 13', 'DATE')
# ('Congress', 'ORG')
# ('1', 'CARDINAL')
# ('1963', 'DATE')
# ('New Hampshire', 'GPE')
# ('June 12, 1963', 'DATE')
# ('Kentucky', 'GPE')
# ('June 27, 1963', 'DATE')
# ('Maine', 'GPE')
# ('January 16, 1964', 'DATE')
# ('South Dakota', 'GPE')
# ('January 23, 1964', 'DATE')
# ('17So', 'CARDINAL')
# ('THE UNITED STATES OF AMERICA—1787', 'ORG')
# ('Senate', 'ORG')
# ('Feb. 19, 1965', 'DATE')
# ('Ratification', 'GPE')
# ('July 1, 1971', 'DATE')
# ('House of Representatives', 'ORG')
# ('Apr. 13', 'DATE')
# ('1965', 'DATE')
# ('The House of Representatives', 'ORG')
# ('July 8, 1971', 'DATE')
# ('Wyoming', 'GPE')
# ('July 8, 1971', 'DATE')
# ('Georgia', 'GPE')
# ('June 30, 1965', 'DATE')
# ('Senate', 'ORG')
# ('4, 1971', 'DATE')
# ('South Dakota', 'GPE')
# ('March 10, 2014', 'DATE')
# ('the Conference Report', 'LAW')
# ('July 6, 1965', 'DATE')
# ('the Administrator of General Services', 'ORG')
# ('CERTIFICATION', 'ORG')
# ('Feb. 23, 1967', 'DATE')
# ('Publication', 'PRODUCT')
# ('39', 'CARDINAL')
# ('50', 'CARDINAL')
# ('States', 'GPE')
# ('General Services', 'ORG')
# ('States', 'GPE')
# ('July 7, 1971', 'DATE')
# ('F.R. Doc', 'PERSON')
# ('Nebraska', 'GPE')
# ('July 12, 1965', 'DATE')
# ('Wisconsin', 'GPE')
# ('July 13, 1965', 'DATE')
# ('71–9691', 'CARDINAL')
# ('36', 'CARDINAL')
# ('F.R. 12725', 'DATE')
# ('Oklahoma', 'GPE')
# ('July 16, 1965', 'DATE')
# ('Massachusetts', 'GPE')
# ('August 9, 1965', 'DATE')
# ('Pennsylvania', 'GPE')
# ('August 18, 1965', 'DATE')
# ('Kentucky', 'GPE')
# ('September 15', 'DATE')
# ('ARTICLE', 'LAW')
# ('XXVII', 'ORG')
# ('1965', 'DATE')
# ('Arizona', 'GPE')
# ('September 22, 1965', 'DATE')
# ('Michigan', 'GPE')
# ('October 5, 1965', 'DATE')
# ('Indiana', 'GPE')
# ('October 20, 1965', 'DATE')
# ('California', 'GPE')
# ('October 21', 'DATE')
# ('1965', 'DATE')
# ('Arkansas', 'GPE')
# ('November 4, 1965', 'DATE')
# ('New Jersey', 'GPE')
# ('Novem-', 'PERSON')
# ('29, 1965', 'DATE')
# ('Delaware', 'GPE')
# ('December 7, 1965', 'DATE')
# ('Utah', 'GPE')
# ('January', 'DATE')
# ('West Virginia', 'GPE')
# ('January 20, 1966', 'DATE')
# ('Maine', 'GPE')
# ('24, 1966', 'DATE')
# ('Rhode Island', 'GPE')
# ('January 28, 1966', 'DATE')
# ('Colorado', 'GPE')
# ('February 3, 1966', 'DATE')
# ('New Mexico', 'GPE')
# ('February 3, 1966', 'DATE')
# ('Kansas', 'GPE')
# ('February 8, 1966', 'DATE')
# ('Vermont', 'GPE')
# ('February 10, 1966', 'DATE')
# ('Alaska', 'GPE')
# ('second', 'ORDINAL')
# ('twelve', 'CARDINAL')
# ('February 18, 1966', 'DATE')
# ('Idaho', 'GPE')
# ('March 2, 1966', 'DATE')
# ('Hawaii', 'GPE')
# ('March', 'DATE')
# ('the First Congress', 'ORG')
# ('Sept. 25, 1789', 'DATE')
# ('3, 1966', 'DATE')
# ('Virginia', 'GPE')
# ('March 8, 1966', 'DATE')
# ('Mississippi', 'GPE')
# ('March 10', 'DATE')
# ('Archivist', 'NORP')
# ('the United States', 'GPE')
# ('May 18, 1966', 'DATE')
# ('New York', 'GPE')
# ('March 14, 1966', 'DATE')
# ('Maryland', 'GPE')
# ('March 23, 1992', 'DATE')
# ('40 of 1966', 'DATE')
# ('Missouri', 'GPE')
# ('March 30, 1966', 'DATE')
# ('New Hampshire', 'GPE')
# ('June 13', 'DATE')
# ('50', 'CARDINAL')
# ('States', 'GPE')
# ('1966', 'DATE')
# ('Louisiana', 'GPE')
# ('July 5, 1966', 'DATE')
# ('Tennessee', 'GPE')
# ('January 12', 'DATE')
# ('1967', 'DATE')
# ('Wyoming', 'GPE')
# ('January 25, 1967', 'DATE')
# ('Washington', 'GPE')
# ('January', 'DATE')
# ('Maryland', 'GPE')
# ('December 19, 1789', 'DATE')
# ('North Carolina', 'GPE')
# ('December 26, 1967', 'DATE')
# ('Iowa', 'GPE')
# ('January 26, 1967', 'DATE')
# ('Oregon', 'GPE')
# ('February 2', 'DATE')
# ('22, 1789', 'DATE')
# ('South Carolina', 'GPE')
# ('January 19, 1790', 'DATE')
# ('Delaware', 'GPE')
# ('1967', 'DATE')
# ('Minnesota', 'GPE')
# ('February 10, 1967', 'DATE')
# ('Nevada', 'GPE')
# ('February 10, January 28, 1790', 'DATE')
# ('Vermont', 'GPE')
# ('November 3, 1791', 'DATE')
# ('Virginia', 'GPE')
# ('1967', 'DATE')
# ('December 15, 1791', 'DATE')
# ('Ohio', 'GPE')
# ('May 6, 1873', 'DATE')
# ('Wyoming', 'GPE')
# ('March', 'DATE')
# ('February 10, 1967', 'DATE')
# ('6, 1978', 'DATE')
# ('Maine', 'GPE')
# ('April 27, 1983', 'DATE')
# ('Colorado', 'GPE')
# ('April 22, 1984', 'DATE')
# ('South Dakota', 'GPE')
# ('February 21, 1985', 'DATE')
# ('New Hampshire', 'GPE')
# ('February 14, 1967', 'DATE')
# ('Montana', 'GPE')
# ('February 15, 1967', 'DATE')
# ('March 7, 1985', 'DATE')
# ('Arizona', 'GPE')
# ('April 3, 1985', 'DATE')
# ('Tennessee', 'GPE')
# ('May 23', 'DATE')
# ('South Dakota', 'GPE')
# ('March 6, 1967', 'DATE')
# ('Ohio', 'GPE')
# ('March 7, 1967', 'DATE')
# ('1985', 'DATE')
# ('Oklahoma', 'GPE')
# ('July 10, 1985', 'DATE')
# ('New Mexico', 'GPE')
# ('February 14', 'DATE')
# ('March 14, 1967', 'DATE')
# ('North Carolina', 'GPE')
# ('March 22, 1967', 'DATE')
# ('1986', 'DATE')
# ('Indiana', 'GPE')
# ('February 24, 1986', 'DATE')
# ('Utah', 'GPE')
# ('February 25, 1986', 'DATE')
# ('linois', 'GPE')
# ('March 22, 1967', 'DATE')
# ('Texas', 'GPE')
# ('April 25, 1967', 'DATE')
# ('Florida', 'GPE')
# ('Arkansas', 'GPE')
# ('March 6, 1987', 'DATE')
# ('Montana', 'GPE')
# ('March 17, 1987', 'DATE')
# ('May 25, 1967', 'DATE')
# ('May 13, 1987', 'DATE')
# ('Wisconsin', 'GPE')
# ('July 15, 1987', 'DATE')
# ('Georgia', 'GPE')
# ('CERTIFICATION', 'ORG')
# ('February 2, 1988', 'DATE')
# ('West Virginia', 'GPE')
# ('March 10, 1988', 'DATE')
# ('Louisi- ana', 'FAC')
# ('July 7, 1988', 'DATE')
# ('Iowa', 'GPE')
# ('February 9, 1989', 'DATE')
# ('Idaho', 'GPE')
# ('23, 1989', 'DATE')
# ('Nevada', 'GPE')
# ('April 26, 1989', 'DATE')
# ('Alaska', 'GPE')
# ('May 6, 1989', 'DATE')
# ('General Services', 'ORG')
# ('egon', 'GPE')
# ('May 19, 1989', 'DATE')
# ('Minnesota', 'GPE')
# ('May 22, 1989', 'DATE')
# ('Texas', 'GPE')
# ('May', 'DATE')
# ('Feb. 25, 1967', 'DATE')
# ('F.R. Doc', 'PERSON')
# ('25, 1989', 'DATE')
# ('Kansas', 'GPE')
# ('April 5, 1990', 'DATE')
# ('Florida', 'GPE')
# ('May 31, 1990', 'DATE')
# ('67–2208', 'CARDINAL')
# ('32', 'CARDINAL')
# ('3287', 'DATE')
# ('North Dakota', 'GPE')
# ('March 25, 1991', 'DATE')
# ('Alabama', 'GPE')
# ('May 5, 1992', 'DATE')
# ('Missouri', 'GPE')
# ('May 5, 1992', 'DATE')
# ('Michigan', 'GPE')
# ('May 7, 1992', 'DATE')
# ('ARTICLE', 'LAW')
# ('XXVI', 'PERSON')
# ('May 7, 1992', 'DATE')
# ('the United Ratification', 'GPE')
# ('May 7, 1992', 'DATE')
# ('eighteen years of age or older', 'DATE')
# ('Illinois', 'GPE')
# ('May 12, 1992', 'DATE')
# ('California', 'GPE')
# ('June 26, 1992', 'DATE')
# ('Rhode Island', 'GPE')
# ('the June 10, 1993', 'DATE')
# ('Hawaii', 'GPE')
# ('April 29, 1994', 'DATE')
# ('Washington', 'GPE')
# ('April United States', 'GPE')
# ('State', 'ORG')
# ('age.', 'DATE')
# ('Kentucky', 'GPE')
# ('March 21, 1996', 'DATE')
# ('SEC', 'ORG')
# ('2', 'CARDINAL')
# ('Congress', 'ORG')
# ('the United States', 'GPE')
# ('May 18, 1992', 'DATE')
# ('F.R. Doc', 'PERSON')
# ('Congress', 'ORG')
# ('Senate', 'ORG')
# ('57', 'CARDINAL')
# ('F.R. 21187', 'DATE')
# ('Senate', 'ORG')
# ('Mar. 10, 1971', 'DATE')
# ('the House of Representatives', 'ORG')
# ('Mar. 23, 1971', 'DATE')
# ('the Administrator of General Services', 'ORG')
# ('THE July 5, 1971', 'DATE')
# ('39', 'CARDINAL')
# ('50', 'CARDINAL')
# ('States', 'GPE')
# ('27', 'CARDINAL')
# ('Connecticut', 'GPE')
# ('March 23, 1971', 'DATE')
# ('Delaware', 'GPE')
# ('March 23, 1971', 'DATE')
# ('three-fourths', 'CARDINAL')
# ('Minnesota', 'GPE')
# ('March 23, 1971', 'DATE')
# ('Tennessee', 'GPE')
# ('March 23, 1971', 'DATE')
# ('States', 'GPE')
# ('six', 'CARDINAL')
# ('Washington', 'GPE')
# ('March 23, 1971', 'DATE')
# ('Hawaii', 'GPE')
# ('March 24, 1971', 'DATE')
# ('States', 'GPE')
# ('Massachusetts', 'GPE')
# ('March 24, 1971', 'DATE')
# ('Montana', 'GPE')
# ('March 29, 1971', 'DATE')
# ('Arkansas', 'GPE')
# ('March 30, 1971', 'DATE')
# ('Idaho', 'GPE')
# ('March 30, 1971', 'DATE')
# ('Iowa', 'GPE')
# ('Eighteenth March 30, 1971', 'FAC')
# ('Nebraska', 'GPE')
# ('April 2, 1971', 'DATE')
# ('New Jersey', 'GPE')
# ('April 3, 1971', 'DATE')
# ('Kansas', 'GPE')
# ('April 7, 1971', 'DATE')
# ('Michigan', 'GPE')
# ('April 7, Amendment', 'DATE')
# ('Congress', 'ORG')
# ('1971', 'DATE')
# ('Alaska', 'GPE')
# ('April 8, 1971', 'DATE')
# ('Maryland', 'GPE')
# ('April 8, 1971', 'DATE')
# ('seven', 'CARDINAL')
# ('April 8, 1971', 'DATE')
# ('Maine', 'GPE')
# ('April 9, 1971', 'DATE')
# ('Vermont', 'GPE')
# ('April years', 'DATE')
# ('the 16, 1971', 'DATE')
# ('Louisiana', 'GPE')
# ('April 17, 1971', 'DATE')
# ('California', 'GPE')
# ('April 19', 'DATE')
# ('States', 'GPE')
# ('The Supreme Court', 'ORG')
# ('Coleman', 'PERSON')
# ('Miller', 'PERSON')
# ('1971', 'DATE')
# ('Colorado', 'GPE')
# ('April 27, 1971', 'DATE')
# ('Pennsylvania', 'GPE')
# ('April 27', 'DATE')
# ('307', 'CARDINAL')
# ('U.S.', 'GPE')
# ('1971', 'DATE')
# ('Texas', 'GPE')
# ('April 27, 1971', 'DATE')
# ('South Carolina', 'GPE')
# ('April 28, 1971', 'DATE')
# ('West Virginia', 'GPE')
# ('April 28, 1971', 'DATE')
# ('New Hampshire', 'GPE')
# ('May 13', 'DATE')
# ('States', 'GPE')
# ('1971', 'DATE')
# ('Arizona', 'GPE')
# ('May 14, 1971', 'DATE')
# ('Rhode Island', 'GPE')
# ('May 27, 1971', 'DATE')
# ('Congress', 'ORG')
# ('New York', 'GPE')
# ('June 2, 1971', 'DATE')
# ('Oregon', 'GPE')
# ('June 4, 1971', 'DATE')
# ('Missouri', 'GPE')
# ('June 14, 1971', 'DATE')
# ('Wisconsin', 'GPE')
# ('June 22, 1971', 'DATE')
# ('Illinois', 'GPE')
# ('June 29', 'DATE')
# ('1789', 'DATE')
# ('twelve', 'CARDINAL')
# ('1971', 'DATE')
# ('Alabama', 'GPE')
# ('June 30, 1971', 'DATE')
# ('Ohio', 'GPE')
# ('June 30, 1971', 'DATE')
# ('North', 'LOC')
# ('States', 'GPE')
# ('Articles Carolina', 'GPE')
# ('July 1, 1971', 'DATE')
# ('Oklahoma', 'GPE')
# ('July 1, 1971', 'DATE')
# ('XII', 'ORG')
# ('first', 'ORDINAL')
# ('THE UNITED STATES OF AMERICA—1787 Page XIV', 'ORG')
# ('Constitution', 'LAW')
# ('the Bill of Rights', 'LAW')
# ('1992', 'DATE')
# ('State', 'ORG')

# %%
def extract_relationships(entities, articles):
    relationships = []
    for article_entities, text in zip(entities, articles):
        article_relationships = []
        doc = nlp(text)
        for ent1 in doc.ents:
            for ent2 in doc.ents:
                if ent1 != ent2:  # Ensure different entities
                    # Example condition: finding relationships based on proximity or specific keywords
                    if ent1.label_ == "ORG" and "passes" in text and ent2.label_ == "LAW":
                        article_relationships.append((ent1.text, "passes", ent2.text))
        relationships.append(article_relationships)
    return relationships

constitution_relationships = extract_relationships(constitution_entities, cleaned_articles)

# %%
# Assuming constitution_entities and constitution_relationships are already defined
node_set = set()
edge_list = []

for article_entities in constitution_entities:
    for entity in article_entities:
        node_set.add((entity[0], entity[1]))  # (entity_text, entity_type)

for article_relationships in constitution_relationships:
    for relation in article_relationships:
        edge_list.append(relation)  # (source_entity, relationship, target_entity)

# Convert sets to list for easier processing later
node_list = list(node_set)

# %%
node_dict = {node[0]: idx for idx, node in enumerate(node_list)}
normalized_edges = [(node_dict[rel[0]], rel[1], node_dict[rel[2]]) for rel in edge_list]

# %%
import chromadb

# Assuming you have a ChromaDB client instance
client = chromadb.Client()

for node in node_list:
    client.insert_node(node_id=node_dict[node[0]], name=node[0], type=node[1])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import chromadb
#       3 # Assuming you have a ChromaDB client instance
#       4 client = chromadb.Client()
#
# ModuleNotFoundError: No module named 'chromadb'
